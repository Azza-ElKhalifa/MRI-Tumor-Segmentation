# %% [markdown]
# # Brain tumor 3D segmentation
# The Brain Tumor Segmentation (BraTS) 2021 Challenge focuses on 3D segmentation of brain tumors, specifically gliomas, from magnetic resonance imaging (MRI) scans. This challenge is part of the larger MICCAI (Medical Image Computing and Computer-Assisted Intervention) competition and is intended to push forward advancements in the automated analysis of brain tumors.

# %% [markdown]
# ## Setup environment

# %%
# !pip install "monai-weekly[nibabel, tqdm]" matplotlib onnxruntime
# Out:
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (3.7.5)
# Collecting onnxruntime
#   Downloading onnxruntime-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting monai-weekly[nibabel,tqdm]
#   Downloading monai_weekly-1.5.dev2443-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: torch>=1.9 in /opt/conda/lib/python3.10/site-packages (from monai-weekly[nibabel,tqdm]) (2.4.0)
# Requirement already satisfied: numpy<2.0,>=1.24 in /opt/conda/lib/python3.10/site-packages (from monai-weekly[nibabel,tqdm]) (1.26.4)
# Requirement already satisfied: tqdm>=4.47.0 in /opt/conda/lib/python3.10/site-packages (from monai-weekly[nibabel,tqdm]) (4.66.4)
# Requirement already satisfied: nibabel in /opt/conda/lib/python3.10/site-packages (from monai-weekly[nibabel,tqdm]) (5.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /opt/conda/lib/python3.10/site-packages (from onnxruntime) (24.3.25)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.10/site-packages (from onnxruntime) (3.20.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from onnxruntime) (1.13.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai-weekly[nibabel,tqdm]) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai-weekly[nibabel,tqdm]) (4.12.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai-weekly[nibabel,tqdm]) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai-weekly[nibabel,tqdm]) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.9->monai-weekly[nibabel,tqdm]) (2024.6.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->onnxruntime) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.9->monai-weekly[nibabel,tqdm]) (2.1.5)
# Downloading onnxruntime-1.19.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 78.0 MB/s eta 0:00:00:00:01:01
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.8 MB/s eta 0:00:00
# Downloading monai_weekly-1.5.dev2443-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 55.5 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.8 MB/s eta 0:00:00
# Installing collected packages: humanfriendly, coloredlogs, onnxruntime, monai-weekly
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 monai-weekly-1.5.dev2443 onnxruntime-1.19.2

# %%
import monai
import matplotlib
import onnxruntime 
# %matplotlib inline

# %% [markdown]
# ## Setup imports

# %%
import os
import shutil
import tempfile
import time
import matplotlib.pyplot as plt
from monai.apps import DecathlonDataset
from monai.config import print_config
from monai.data import DataLoader, decollate_batch
from monai.handlers.utils import from_engine
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
from monai.metrics import DiceMetric
from monai.networks.nets import SegResNet
from monai.transforms import (
    Activations,
    Activationsd,
    AsDiscrete,
    AsDiscreted,
    Compose,
    Invertd,
    LoadImaged,
    MapTransform,
    NormalizeIntensityd,
    Orientationd,
    RandFlipd,
    RandScaleIntensityd,
    RandShiftIntensityd,
    RandSpatialCropd,
    Spacingd,
    EnsureTyped,
    EnsureChannelFirstd,
)
from monai.utils import set_determinism
import onnxruntime
from tqdm import tqdm

import torch

print_config()
# Out:
# MONAI version: 1.5.dev2443
# Numpy version: 1.26.4
# Pytorch version: 2.4.0
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: d508ba780862a6459326c812e09188838c25bdc5
# MONAI __file__: /opt/conda/lib/python3.10/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.5.1
# ITK version: NOT INSTALLED or UNKNOWN VERSION.
# Nibabel version: 5.2.1
# scikit-image version: 0.23.2
# scipy version: 1.14.1
# Pillow version: 10.4.0
# Tensorboard version: 2.16.2
# gdown version: NOT INSTALLED or UNKNOWN VERSION.
# TorchVision version: 0.19.0
# tqdm version: 4.66.4
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 5.9.3
# pandas version: 2.2.3
# einops version: NOT INSTALLED or UNKNOWN VERSION.
# transformers version: 4.45.1
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
# clearml version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %% [markdown]
# ## Setup data directory
#
# You can specify a directory with the `MONAI_DATA_DIRECTORY` environment variable.
# This allows you to save results and reuse downloads.
# If not specified a temporary directory will be used.

# %%
directory = "/kaggle/working"
if directory is not None:
    os.makedirs(directory, exist_ok=True)
root_dir = tempfile.mkdtemp() if directory is None else directory
print(root_dir)
# Out:
# /kaggle/working

# %% [markdown]
# ## Set deterministic training for reproducibility

# %%
set_determinism(seed=0)

# %% [markdown]
# ## Define a new transform to convert brain tumor labels
#
# Here we convert the multi-classes labels into multi-labels segmentation task in One-Hot format.

# %%
class ConvertToMultiChannelBasedOnBratsClassesd(MapTransform):
    """
    Convert labels to multi channels based on brats classes:
    label 1 is the peritumoral edema
    label 2 is the GD-enhancing tumor
    label 3 is the necrotic and non-enhancing tumor core
    The possible classes are TC (Tumor core), WT (Whole tumor)
    and ET (Enhancing tumor).

    """

    def __call__(self, data):
        d = dict(data)
        for key in self.keys:
            result = []
            # merge label 2 and label 3 to construct TC
            result.append(torch.logical_or(d[key] == 2, d[key] == 3))
            # merge labels 1, 2 and 3 to construct WT
            result.append(torch.logical_or(torch.logical_or(d[key] == 2, d[key] == 3), d[key] == 1))
            # label 2 is ET
            result.append(d[key] == 2)
            d[key] = torch.stack(result, axis=0).float()
        return d

# %% [markdown]
# ## Setup transforms for training and validation

# %%
train_transform = Compose(
    [
        # load 4 Nifti images and stack them together
        LoadImaged(keys=["image", "label"]),
        EnsureChannelFirstd(keys="image"),
        EnsureTyped(keys=["image", "label"]),
        ConvertToMultiChannelBasedOnBratsClassesd(keys="label"),
        Orientationd(keys=["image", "label"], axcodes="RAS"),
        Spacingd(
            keys=["image", "label"],
            pixdim=(1.0, 1.0, 1.0),
            mode=("bilinear", "nearest"),
        ),
        RandSpatialCropd(keys=["image", "label"], roi_size=[224, 224, 144], random_size=False),
        RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=0),
        RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=1),
        RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=2),
        NormalizeIntensityd(keys="image", nonzero=True, channel_wise=True),
        RandScaleIntensityd(keys="image", factors=0.1, prob=1.0),
        RandShiftIntensityd(keys="image", offsets=0.1, prob=1.0),
    ]
)
val_transform = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        EnsureChannelFirstd(keys="image"),
        EnsureTyped(keys=["image", "label"]),
        ConvertToMultiChannelBasedOnBratsClassesd(keys="label"),
        Orientationd(keys=["image", "label"], axcodes="RAS"),
        Spacingd(
            keys=["image", "label"],
            pixdim=(1.0, 1.0, 1.0),
            mode=("bilinear", "nearest"),
        ),
        NormalizeIntensityd(keys="image", nonzero=True, channel_wise=True),
    ]
)

# %% [markdown]
# ## Quickly load data with DecathlonDataset
#
# Here we use `DecathlonDataset` to automatically download and extract the dataset.
# It inherits MONAI `CacheDataset`, if you want to use less memory, you can set `cache_num=N` to cache N items for training and use the default args to cache all the items for validation, it depends on your memory size.

# %%
# here we don't cache any data in case out of memory issue
train_ds = DecathlonDataset(
    root_dir=root_dir,
    task="Task01_BrainTumour",
    transform=train_transform,
    section="training",
    download=True,
    cache_rate=0.0,
    num_workers=4,
)
train_loader = DataLoader(train_ds, batch_size=1, shuffle=True, num_workers=4)
val_ds = DecathlonDataset(
    root_dir=root_dir,
    task="Task01_BrainTumour",
    transform=val_transform,
    section="validation",
    download=False,
    cache_rate=0.0,
    num_workers=4,
)
val_loader = DataLoader(val_ds, batch_size=1, shuffle=False, num_workers=4)
# Out:
# Task01_BrainTumour.tar: 7.09GB [02:58, 42.6MB/s]
# 2024-10-28 07:00:07,709 - INFO - Downloaded: /kaggle/working/Task01_BrainTumour.tar
# 2024-10-28 07:00:21,103 - INFO - Verified 'Task01_BrainTumour.tar', md5: 240a19d752f0d9e9101544901065d872.
# 2024-10-28 07:00:21,104 - INFO - Writing into directory: /kaggle/working.

# %% [markdown]
# ## Check data shape and visualize

# %%
# pick one image from DecathlonDataset to visualize and check the 4 channels
val_data_example = val_ds[2]
print(f"image shape: {val_data_example['image'].shape}")
plt.figure("image", (24, 6))
for i in range(4):
    plt.subplot(1, 4, i + 1)
    plt.title(f"image channel {i}")
    plt.imshow(val_data_example["image"][i, :, :, 60].detach().cpu(), cmap="gray")
plt.show()
# also visualize the 3 channels label corresponding to this image
print(f"label shape: {val_data_example['label'].shape}")
plt.figure("label", (18, 6))
for i in range(3):
    plt.subplot(1, 3, i + 1)
    plt.title(f"label channel {i}")
    plt.imshow(val_data_example["label"][i, :, :, 60].detach().cpu())
plt.show()
# Out:
# image shape: torch.Size([4, 240, 240, 155])
# label shape: torch.Size([3, 240, 240, 155])

# %% [markdown]
# ## Create Model, Loss, Optimizer

# %%
max_epochs = 50
val_interval = 1
VAL_AMP = True

# standard PyTorch program style: create SegResNet, DiceLoss and Adam optimizer
device = torch.device("cuda:0")
model = SegResNet(
    blocks_down=[1, 2, 2, 4],
    blocks_up=[1, 1, 1],
    init_filters=16,
    in_channels=4,
    out_channels=3,
    dropout_prob=0.2,
).to(device)
loss_function = DiceLoss(smooth_nr=0, smooth_dr=1e-5, squared_pred=True, to_onehot_y=False, sigmoid=True)
optimizer = torch.optim.Adam(model.parameters(), 1e-4, weight_decay=1e-5)
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=max_epochs)

dice_metric = DiceMetric(include_background=True, reduction="mean")
dice_metric_batch = DiceMetric(include_background=True, reduction="mean_batch")

post_trans = Compose([Activations(sigmoid=True), AsDiscrete(threshold=0.5)])


# define inference method
def inference(input):
    def _compute(input):
        return sliding_window_inference(
            inputs=input,
            roi_size=(240, 240, 160),
            sw_batch_size=1,
            predictor=model,
            overlap=0.5,
        )

    if VAL_AMP:
        with torch.cuda.amp.autocast():
            return _compute(input)
    else:
        return _compute(input)


# use amp to accelerate training
scaler = torch.cuda.amp.GradScaler()
# enable cuDNN benchmark
torch.backends.cudnn.benchmark = True
# Out:
# /tmp/ipykernel_30/1147902317.py:44: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()

# %% [markdown]
# ## Execute a typical PyTorch training process

# %%
best_metric = -1
best_metric_epoch = -1
best_metrics_epochs_and_time = [[], [], []]
epoch_loss_values = []
metric_values = []
metric_values_tc = []
metric_values_wt = []
metric_values_et = []

total_start = time.time()
for epoch in range(max_epochs):
    epoch_start = time.time()
    print("-" * 10)
    print(f"epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step_start = time.time()
        step += 1
        inputs, labels = (
            batch_data["image"].to(device),
            batch_data["label"].to(device),
        )
        optimizer.zero_grad()
        with torch.cuda.amp.autocast():
            outputs = model(inputs)
            loss = loss_function(outputs, labels)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        epoch_loss += loss.item()
        print(
            f"{step}/{len(train_ds) // train_loader.batch_size}"
            f", train_loss: {loss.item():.4f}"
            f", step time: {(time.time() - step_start):.4f}"
        )
    lr_scheduler.step()
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    if (epoch + 1) % val_interval == 0:
        model.eval()
        with torch.no_grad():
            for val_data in val_loader:
                val_inputs, val_labels = (
                    val_data["image"].to(device),
                    val_data["label"].to(device),
                )
                val_outputs = inference(val_inputs)
                val_outputs = [post_trans(i) for i in decollate_batch(val_outputs)]
                dice_metric(y_pred=val_outputs, y=val_labels)
                dice_metric_batch(y_pred=val_outputs, y=val_labels)

            metric = dice_metric.aggregate().item()
            metric_values.append(metric)
            metric_batch = dice_metric_batch.aggregate()
            metric_tc = metric_batch[0].item()
            metric_values_tc.append(metric_tc)
            metric_wt = metric_batch[1].item()
            metric_values_wt.append(metric_wt)
            metric_et = metric_batch[2].item()
            metric_values_et.append(metric_et)
            dice_metric.reset()
            dice_metric_batch.reset()

            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                best_metrics_epochs_and_time[0].append(best_metric)
                best_metrics_epochs_and_time[1].append(best_metric_epoch)
                best_metrics_epochs_and_time[2].append(time.time() - total_start)
                torch.save(
                    model.state_dict(),
                    os.path.join(root_dir, "best_metric_model.pth"),
                )
                print("saved new best metric model")
            print(
                f"current epoch: {epoch + 1} current mean dice: {metric:.4f}"
                f" tc: {metric_tc:.4f} wt: {metric_wt:.4f} et: {metric_et:.4f}"
                f"\nbest mean dice: {best_metric:.4f}"
                f" at epoch: {best_metric_epoch}"
            )
    print(f"time consuming of epoch {epoch + 1} is: {(time.time() - epoch_start):.4f}")
total_time = time.time() - total_start
# Out:
# ----------
# epoch 1/50
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /tmp/ipykernel_30/2626221911.py:26: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# 1/388, train_loss: 0.9782, step time: 8.7149
# 2/388, train_loss: 0.9804, step time: 0.9688
# 3/388, train_loss: 0.9880, step time: 0.9743
# 4/388, train_loss: 0.9565, step time: 0.9973
# 5/388, train_loss: 0.9837, step time: 0.9902
# 6/388, train_loss: 0.9386, step time: 1.0102
# 7/388, train_loss: 0.9720, step time: 0.9806
# 8/388, train_loss: 0.9391, step time: 1.0075
# 9/388, train_loss: 0.9850, step time: 1.0626
# 10/388, train_loss: 0.9426, step time: 1.0819
# 11/388, train_loss: 0.8942, step time: 1.0284
# 12/388, train_loss: 0.8891, step time: 0.9873
# 13/388, train_loss: 0.9641, step time: 1.0000
# 14/388, train_loss: 0.8992, step time: 1.0210
# 15/388, train_loss: 0.9293, step time: 1.0489
# 16/388, train_loss: 0.9565, step time: 1.0107
# 17/388, train_loss: 0.9710, step time: 1.0012
# 18/388, train_loss: 0.9358, step time: 1.0019
# 19/388, train_loss: 0.9587, step time: 0.9856
# 20/388, train_loss: 0.8866, step time: 0.9974
# 21/388, train_loss: 0.9416, step time: 1.0013
# 22/388, train_loss: 0.9378, step time: 0.9904
# 23/388, train_loss: 0.9301, step time: 1.0048
# 24/388, train_loss: 0.9364, step time: 1.0466
# 25/388, train_loss: 0.9509, step time: 1.0285
# 26/388, train_loss: 0.9509, step time: 0.9937
# 27/388, train_loss: 0.9824, step time: 1.0052
# 28/388, train_loss: 0.9501, step time: 1.0394
# 29/388, train_loss: 0.9560, step time: 1.0512
# 30/388, train_loss: 0.9362, step time: 1.0385
# 31/388, train_loss: 0.9679, step time: 1.0108
# 32/388, train_loss: 0.9924, step time: 1.0144
# 33/388, train_loss: 0.9339, step time: 1.0186
# 34/388, train_loss: 0.9586, step time: 1.0925
# 35/388, train_loss: 0.9481, step time: 1.0207
# 36/388, train_loss: 0.9330, step time: 0.9972
# 37/388, train_loss: 0.9021, step time: 0.9943
# 38/388, train_loss: 0.9795, step time: 1.0043
# 39/388, train_loss: 0.8883, step time: 1.0007
# 40/388, train_loss: 0.9005, step time: 1.0296
# 41/388, train_loss: 0.9876, step time: 1.0683
# 42/388, train_loss: 0.9528, step time: 1.0841
# 43/388, train_loss: 0.9060, step time: 1.0164
# 44/388, train_loss: 0.9228, step time: 1.0602
# 45/388, train_loss: 0.9626, step time: 1.0817
# 46/388, train_loss: 0.9389, step time: 1.0480
# 47/388, train_loss: 0.9280, step time: 1.0361
# 48/388, train_loss: 0.9632, step time: 1.0205
# 49/388, train_loss: 0.8556, step time: 1.0209
# 50/388, train_loss: 0.9882, step time: 1.0161
# 51/388, train_loss: 0.9889, step time: 1.0101
# 52/388, train_loss: 0.9618, step time: 1.0227
# 53/388, train_loss: 0.8086, step time: 1.0501
# 54/388, train_loss: 0.9434, step time: 1.0438
# 55/388, train_loss: 0.9103, step time: 1.0991
# 56/388, train_loss: 0.9641, step time: 1.0182
# 57/388, train_loss: 0.9493, step time: 1.0241
# 58/388, train_loss: 0.9447, step time: 1.0166
# 59/388, train_loss: 0.9568, step time: 1.0248
# 60/388, train_loss: 0.9640, step time: 1.0294
# 61/388, train_loss: 0.9409, step time: 1.0969
# 62/388, train_loss: 0.9046, step time: 1.0196
# 63/388, train_loss: 0.8753, step time: 1.0722
# 64/388, train_loss: 0.9404, step time: 1.0231
# 65/388, train_loss: 0.9603, step time: 1.0230
# 66/388, train_loss: 0.9597, step time: 1.0245
# 67/388, train_loss: 0.8826, step time: 1.0408
# 68/388, train_loss: 0.7838, step time: 1.0264
# 69/388, train_loss: 0.8873, step time: 1.0112
# 70/388, train_loss: 0.9051, step time: 1.0536
# 71/388, train_loss: 0.9497, step time: 1.0013
# 72/388, train_loss: 0.9349, step time: 1.0192
# 73/388, train_loss: 0.9163, step time: 1.0045
# 74/388, train_loss: 0.9294, step time: 1.0214
# 75/388, train_loss: 0.9898, step time: 1.0228
# 76/388, train_loss: 0.9107, step time: 1.0084
# 77/388, train_loss: 0.9358, step time: 1.0270
# 78/388, train_loss: 0.8877, step time: 1.0230
# 79/388, train_loss: 0.8787, step time: 1.0807
# 80/388, train_loss: 0.9924, step time: 1.0308
# 81/388, train_loss: 0.9834, step time: 1.0199
# 82/388, train_loss: 0.9063, step time: 1.0322
# 83/388, train_loss: 0.9681, step time: 1.0342
# 84/388, train_loss: 0.9530, step time: 1.0207
# 85/388, train_loss: 0.9167, step time: 1.0276
# 86/388, train_loss: 0.9521, step time: 1.0271
# 87/388, train_loss: 0.9640, step time: 1.0348
# 88/388, train_loss: 0.8528, step time: 1.1088
# 89/388, train_loss: 0.9411, step time: 1.1240
# 90/388, train_loss: 0.9957, step time: 1.0288
# 91/388, train_loss: 0.9819, step time: 1.0331
# 92/388, train_loss: 0.9948, step time: 1.0317
# 93/388, train_loss: 0.9647, step time: 1.0396
# 94/388, train_loss: 0.9139, step time: 1.0250
# 95/388, train_loss: 0.9100, step time: 1.0412
# 96/388, train_loss: 0.9050, step time: 1.0862
# 97/388, train_loss: 0.8294, step time: 1.1369
# 98/388, train_loss: 0.7687, step time: 1.0426
# 99/388, train_loss: 0.9247, step time: 1.0722
# 100/388, train_loss: 0.9132, step time: 1.0450
# 101/388, train_loss: 0.9667, step time: 1.0371
# 102/388, train_loss: 0.8987, step time: 1.0451
# 103/388, train_loss: 0.9028, step time: 1.0647
# 104/388, train_loss: 0.9798, step time: 1.0545
# 105/388, train_loss: 0.9148, step time: 1.0791
# 106/388, train_loss: 0.9717, step time: 1.0461
# 107/388, train_loss: 0.9868, step time: 1.0967
# 108/388, train_loss: 0.9423, step time: 1.0520
# 109/388, train_loss: 0.8263, step time: 1.1151
# 110/388, train_loss: 0.9239, step time: 1.0862
# 111/388, train_loss: 0.9758, step time: 1.0440
# 112/388, train_loss: 0.9183, step time: 1.0572
# 113/388, train_loss: 0.9702, step time: 1.1188
# 114/388, train_loss: 0.9012, step time: 1.1360
# 115/388, train_loss: 0.9334, step time: 1.1382
# 116/388, train_loss: 0.9473, step time: 1.0515
# 117/388, train_loss: 0.9021, step time: 1.0674
# 118/388, train_loss: 0.9437, step time: 1.0667
# 119/388, train_loss: 0.9127, step time: 1.0509
# 120/388, train_loss: 0.8674, step time: 1.0816
# 121/388, train_loss: 0.9382, step time: 1.0652
# 122/388, train_loss: 0.9618, step time: 1.0587
# 123/388, train_loss: 0.9593, step time: 1.0643
# 124/388, train_loss: 0.8713, step time: 1.0708
# 125/388, train_loss: 0.8670, step time: 1.0688
# 126/388, train_loss: 0.9742, step time: 1.0344
# 127/388, train_loss: 0.9738, step time: 1.0526
# 128/388, train_loss: 0.9822, step time: 1.0736
# 129/388, train_loss: 0.9425, step time: 1.0428
# 130/388, train_loss: 0.8942, step time: 1.0460
# 131/388, train_loss: 0.9596, step time: 1.0723
# 132/388, train_loss: 0.9370, step time: 1.0562
# 133/388, train_loss: 0.9273, step time: 1.0576
# 134/388, train_loss: 0.9592, step time: 1.0694
# 135/388, train_loss: 0.9642, step time: 1.1073
# 136/388, train_loss: 0.7986, step time: 1.0555
# 137/388, train_loss: 0.9407, step time: 1.0409
# 138/388, train_loss: 0.9586, step time: 1.0444
# 139/388, train_loss: 0.8904, step time: 1.0305
# 140/388, train_loss: 0.9092, step time: 1.0392
# 141/388, train_loss: 0.9414, step time: 1.0581
# 142/388, train_loss: 0.8801, step time: 1.1232
# 143/388, train_loss: 0.8708, step time: 1.0460
# 144/388, train_loss: 0.9020, step time: 1.0356
# 145/388, train_loss: 0.8879, step time: 1.0448
# 146/388, train_loss: 0.9697, step time: 1.0610
# 147/388, train_loss: 0.9941, step time: 1.0257
# 148/388, train_loss: 0.9643, step time: 1.0345
# 149/388, train_loss: 0.9354, step time: 1.0440
# 150/388, train_loss: 0.9719, step time: 1.0251
# 151/388, train_loss: 0.9287, step time: 1.0505
# 152/388, train_loss: 0.9679, step time: 1.0597
# 153/388, train_loss: 0.8480, step time: 1.0316
# 154/388, train_loss: 0.8826, step time: 1.0363
# 155/388, train_loss: 0.8641, step time: 1.0687
# 156/388, train_loss: 0.7955, step time: 1.0642
# 157/388, train_loss: 0.9080, step time: 1.0362
# 158/388, train_loss: 0.9096, step time: 1.0407
# 159/388, train_loss: 0.9905, step time: 1.0458
# 160/388, train_loss: 0.9759, step time: 1.0505
# 161/388, train_loss: 0.8823, step time: 1.0754
# 162/388, train_loss: 0.9671, step time: 1.0731
# 163/388, train_loss: 0.9225, step time: 1.0633
# 164/388, train_loss: 0.8976, step time: 1.0849
# 165/388, train_loss: 0.9242, step time: 1.0393
# 166/388, train_loss: 0.9659, step time: 1.0761
# 167/388, train_loss: 0.9733, step time: 1.0461
# 168/388, train_loss: 0.8030, step time: 1.0634
# 169/388, train_loss: 0.8602, step time: 1.1314
# 170/388, train_loss: 0.8474, step time: 1.0464
# 171/388, train_loss: 0.9683, step time: 1.0374
# 172/388, train_loss: 0.9759, step time: 1.0528
# 173/388, train_loss: 0.8110, step time: 1.0578
# 174/388, train_loss: 0.9786, step time: 1.0453
# 175/388, train_loss: 0.9753, step time: 1.0356
# 176/388, train_loss: 0.8070, step time: 1.0838
# 177/388, train_loss: 0.9907, step time: 1.1460
# 178/388, train_loss: 0.9496, step time: 1.0526
# 179/388, train_loss: 0.9768, step time: 1.0591
# 180/388, train_loss: 0.9664, step time: 1.0525
# 181/388, train_loss: 0.9839, step time: 1.0384
# 182/388, train_loss: 0.8726, step time: 1.0345
# 183/388, train_loss: 0.9423, step time: 1.0378
# 184/388, train_loss: 0.9096, step time: 1.0748
# 185/388, train_loss: 0.9874, step time: 1.0438
# 186/388, train_loss: 0.9642, step time: 1.0420
# 187/388, train_loss: 0.8025, step time: 1.0609
# 188/388, train_loss: 0.9715, step time: 1.0630
# 189/388, train_loss: 0.9802, step time: 1.0454
# 190/388, train_loss: 0.9231, step time: 1.0560
# 191/388, train_loss: 0.9330, step time: 1.0411
# 192/388, train_loss: 0.9841, step time: 1.0949
# 193/388, train_loss: 0.9543, step time: 1.0391
# 194/388, train_loss: 0.9522, step time: 1.0604
# 195/388, train_loss: 0.8945, step time: 1.1177
# 196/388, train_loss: 0.9379, step time: 1.0484
# 197/388, train_loss: 0.8765, step time: 1.0357
# 198/388, train_loss: 0.9092, step time: 1.0520
# 199/388, train_loss: 0.9626, step time: 1.0422
# 200/388, train_loss: 0.8672, step time: 1.0975
# 201/388, train_loss: 0.9185, step time: 1.0500
# 202/388, train_loss: 0.8971, step time: 1.0541
# 203/388, train_loss: 0.8359, step time: 1.1292
# 204/388, train_loss: 0.8687, step time: 1.0587
# 205/388, train_loss: 0.8886, step time: 1.0463
# 206/388, train_loss: 0.8465, step time: 1.1147
# 207/388, train_loss: 0.9753, step time: 1.0443
# 208/388, train_loss: 0.9530, step time: 1.0426
# 209/388, train_loss: 0.9460, step time: 1.0430
# 210/388, train_loss: 0.9460, step time: 1.0903
# 211/388, train_loss: 0.9280, step time: 1.0484
# 212/388, train_loss: 0.9428, step time: 1.0453
# 213/388, train_loss: 0.7879, step time: 1.0449
# 214/388, train_loss: 0.9565, step time: 1.0495
# 215/388, train_loss: 0.9075, step time: 1.0432
# 216/388, train_loss: 0.8886, step time: 1.0493
# 217/388, train_loss: 0.9447, step time: 1.0625
# 218/388, train_loss: 0.9032, step time: 1.0494
# 219/388, train_loss: 0.7584, step time: 1.0577
# 220/388, train_loss: 0.9203, step time: 1.0620
# 221/388, train_loss: 0.8397, step time: 1.1413
# 222/388, train_loss: 0.9772, step time: 1.1296
# 223/388, train_loss: 0.8040, step time: 1.0949
# 224/388, train_loss: 0.9785, step time: 1.0466
# 225/388, train_loss: 0.8764, step time: 1.0777
# 226/388, train_loss: 0.9691, step time: 1.0591
# 227/388, train_loss: 0.8605, step time: 1.0886
# 228/388, train_loss: 0.8418, step time: 1.0930
# 229/388, train_loss: 0.9020, step time: 1.0953
# 230/388, train_loss: 0.9920, step time: 1.0450
# 231/388, train_loss: 0.9085, step time: 1.0552
# 232/388, train_loss: 0.8292, step time: 1.0715
# 233/388, train_loss: 0.8303, step time: 1.0514
# 234/388, train_loss: 0.9134, step time: 1.0620
# 235/388, train_loss: 0.9838, step time: 1.0427
# 236/388, train_loss: 0.9282, step time: 1.0608
# 237/388, train_loss: 0.9883, step time: 1.0394
# 238/388, train_loss: 0.9795, step time: 1.0724
# 239/388, train_loss: 0.8834, step time: 1.0546
# 240/388, train_loss: 0.8896, step time: 1.0559
# 241/388, train_loss: 0.9537, step time: 1.0737
# 242/388, train_loss: 0.9491, step time: 1.1065
# 243/388, train_loss: 0.7926, step time: 1.0818
# 244/388, train_loss: 0.9226, step time: 1.0328
# 245/388, train_loss: 0.8389, step time: 1.0483
# 246/388, train_loss: 0.9420, step time: 1.0968
# 247/388, train_loss: 0.8886, step time: 1.1236
# 248/388, train_loss: 0.9055, step time: 1.0661
# 249/388, train_loss: 0.9272, step time: 1.0498
# 250/388, train_loss: 0.9202, step time: 1.0688
# 251/388, train_loss: 0.7696, step time: 1.0471
# 252/388, train_loss: 0.8574, step time: 1.1019
# 253/388, train_loss: 0.9829, step time: 1.0346
# 254/388, train_loss: 0.8589, step time: 1.0518
# 255/388, train_loss: 0.9415, step time: 1.0905
# 256/388, train_loss: 0.9859, step time: 1.0285
# 257/388, train_loss: 0.9157, step time: 1.0375
# 258/388, train_loss: 0.9506, step time: 1.0435
# 259/388, train_loss: 0.7925, step time: 1.0412
# 260/388, train_loss: 0.8286, step time: 1.0339
# 261/388, train_loss: 0.9708, step time: 1.0696
# 262/388, train_loss: 0.9755, step time: 1.0474
# 263/388, train_loss: 0.9133, step time: 1.0428
# 264/388, train_loss: 0.9148, step time: 1.0484
# 265/388, train_loss: 0.8764, step time: 1.0346
# 266/388, train_loss: 0.9210, step time: 1.0331
# 267/388, train_loss: 0.9326, step time: 1.0508
# 268/388, train_loss: 0.8455, step time: 1.0455
# 269/388, train_loss: 0.9899, step time: 1.0915
# 270/388, train_loss: 0.9104, step time: 1.1186
# 271/388, train_loss: 0.9642, step time: 1.0459
# 272/388, train_loss: 0.8682, step time: 1.0531
# 273/388, train_loss: 0.8689, step time: 1.0589
# 274/388, train_loss: 0.8605, step time: 1.1110
# 275/388, train_loss: 0.9482, step time: 1.1482
# 276/388, train_loss: 0.9621, step time: 1.0394
# 277/388, train_loss: 0.8280, step time: 1.0477
# 278/388, train_loss: 0.9485, step time: 1.1042
# 279/388, train_loss: 0.8778, step time: 1.0293
# 280/388, train_loss: 0.9556, step time: 1.0420
# 281/388, train_loss: 0.8808, step time: 1.0550
# 282/388, train_loss: 0.8769, step time: 1.0462
# 283/388, train_loss: 0.9321, step time: 1.0698
# 284/388, train_loss: 0.9859, step time: 1.0602
# 285/388, train_loss: 0.9083, step time: 1.0657
# 286/388, train_loss: 0.9424, step time: 1.1083
# 287/388, train_loss: 0.9627, step time: 1.0353
# 288/388, train_loss: 0.8382, step time: 1.1141
# 289/388, train_loss: 0.8826, step time: 1.0439
# 290/388, train_loss: 0.9192, step time: 1.0446
# 291/388, train_loss: 0.9714, step time: 1.0469
# 292/388, train_loss: 0.9088, step time: 1.0425
# 293/388, train_loss: 0.8223, step time: 1.0876
# 294/388, train_loss: 0.9346, step time: 1.0580
# 295/388, train_loss: 0.9013, step time: 1.0554
# 296/388, train_loss: 0.9092, step time: 1.0418
# 297/388, train_loss: 0.9229, step time: 1.0571
# 298/388, train_loss: 0.8818, step time: 1.0435
# 299/388, train_loss: 0.8955, step time: 1.0786
# 300/388, train_loss: 0.8725, step time: 1.1058
# 301/388, train_loss: 0.9543, step time: 1.0328
# 302/388, train_loss: 0.9280, step time: 1.1184
# 303/388, train_loss: 0.9864, step time: 1.1019
# 304/388, train_loss: 0.9180, step time: 1.0377
# 305/388, train_loss: 0.8751, step time: 1.1061
# 306/388, train_loss: 0.9662, step time: 1.0401
# 307/388, train_loss: 0.7795, step time: 1.0729
# 308/388, train_loss: 0.9360, step time: 1.0479
# 309/388, train_loss: 0.9302, step time: 1.0451
# 310/388, train_loss: 0.9217, step time: 1.0517
# 311/388, train_loss: 0.9652, step time: 1.0358
# 312/388, train_loss: 0.9200, step time: 1.0420
# 313/388, train_loss: 0.9203, step time: 1.0499
# 314/388, train_loss: 0.8692, step time: 1.0280
# 315/388, train_loss: 0.9948, step time: 1.0462
# 316/388, train_loss: 0.9202, step time: 1.0473
# 317/388, train_loss: 0.8031, step time: 1.0403
# 318/388, train_loss: 0.8142, step time: 1.0545
# 319/388, train_loss: 0.9152, step time: 1.0448
# 320/388, train_loss: 0.9349, step time: 1.0471
# 321/388, train_loss: 0.8863, step time: 1.0350
# 322/388, train_loss: 0.8342, step time: 1.0416
# 323/388, train_loss: 0.9427, step time: 1.0464
# 324/388, train_loss: 0.9634, step time: 1.0337
# 325/388, train_loss: 0.9006, step time: 1.0462
# 326/388, train_loss: 0.8993, step time: 1.0693
# 327/388, train_loss: 0.9023, step time: 1.0862
# 328/388, train_loss: 0.9496, step time: 1.1414
# 329/388, train_loss: 0.8520, step time: 1.0553
# 330/388, train_loss: 0.8900, step time: 1.0513
# 331/388, train_loss: 0.9733, step time: 1.1074
# 332/388, train_loss: 0.9848, step time: 1.0349
# 333/388, train_loss: 0.8915, step time: 1.0528
# 334/388, train_loss: 0.8462, step time: 1.0454
# 335/388, train_loss: 0.9283, step time: 1.0329
# 336/388, train_loss: 0.9166, step time: 1.0535
# 337/388, train_loss: 0.9857, step time: 1.0430
# 338/388, train_loss: 0.9417, step time: 1.0438
# 339/388, train_loss: 0.9697, step time: 1.0406
# 340/388, train_loss: 0.8664, step time: 1.0556
# 341/388, train_loss: 0.9792, step time: 1.0719
# 342/388, train_loss: 0.8279, step time: 1.0497
# 343/388, train_loss: 0.8566, step time: 1.0533
# 344/388, train_loss: 0.9523, step time: 1.1054
# 345/388, train_loss: 0.7950, step time: 1.0437
# 346/388, train_loss: 0.9209, step time: 1.0728
# 347/388, train_loss: 0.8293, step time: 1.0352
# 348/388, train_loss: 0.9294, step time: 1.0494
# 349/388, train_loss: 0.9115, step time: 1.0400
# 350/388, train_loss: 0.8676, step time: 1.0508
# 351/388, train_loss: 0.9421, step time: 1.0528
# 352/388, train_loss: 0.9325, step time: 1.0955
# 353/388, train_loss: 0.9311, step time: 1.0589
# 354/388, train_loss: 0.8957, step time: 1.0462
# 355/388, train_loss: 0.8159, step time: 1.0787
# 356/388, train_loss: 0.9694, step time: 1.0403
# 357/388, train_loss: 0.8522, step time: 1.1286
# 358/388, train_loss: 0.8985, step time: 1.0527
# 359/388, train_loss: 0.8471, step time: 1.0473
# 360/388, train_loss: 0.8423, step time: 1.0519
# 361/388, train_loss: 0.8734, step time: 1.0506
# 362/388, train_loss: 0.9213, step time: 1.0739
# 363/388, train_loss: 0.9154, step time: 1.0589
# 364/388, train_loss: 0.8826, step time: 1.0572
# 365/388, train_loss: 0.8447, step time: 1.0920
# 366/388, train_loss: 0.8977, step time: 1.0447
# 367/388, train_loss: 0.9416, step time: 1.0710
# 368/388, train_loss: 0.8894, step time: 1.0563
# 369/388, train_loss: 0.9854, step time: 1.0879
# 370/388, train_loss: 0.8313, step time: 1.0675
# 371/388, train_loss: 0.9740, step time: 1.0503
# 372/388, train_loss: 0.9529, step time: 1.0837
# 373/388, train_loss: 0.8920, step time: 1.0499
# 374/388, train_loss: 0.9465, step time: 1.0517
# 375/388, train_loss: 0.8982, step time: 1.0565
# 376/388, train_loss: 0.9284, step time: 1.0636
# 377/388, train_loss: 0.8843, step time: 1.0610
# 378/388, train_loss: 0.9888, step time: 1.0411
# 379/388, train_loss: 0.8613, step time: 1.0394
# 380/388, train_loss: 0.8934, step time: 1.0585
# 381/388, train_loss: 0.9331, step time: 1.0357
# 382/388, train_loss: 0.8516, step time: 1.0517
# 383/388, train_loss: 0.9433, step time: 1.0252
# 384/388, train_loss: 0.9269, step time: 1.0207
# 385/388, train_loss: 0.8387, step time: 1.0177
# 386/388, train_loss: 0.9920, step time: 1.0154
# 387/388, train_loss: 0.7948, step time: 1.0174
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 388/388, train_loss: 0.9649, step time: 1.0182
# epoch 1 average loss: 0.9190
# /tmp/ipykernel_30/1147902317.py:37: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# saved new best metric model
# current epoch: 1 current mean dice: 0.3963 tc: 0.4169 wt: 0.5692 et: 0.2029
# best mean dice: 0.3963 at epoch: 1
# time consuming of epoch 1 is: 580.2735
# ----------
# epoch 2/50
# 1/388, train_loss: 0.8578, step time: 1.1434
# 2/388, train_loss: 0.8241, step time: 1.0914
# 3/388, train_loss: 0.8417, step time: 1.0394
# 4/388, train_loss: 0.8656, step time: 1.1121
# 5/388, train_loss: 0.8891, step time: 1.0756
# 6/388, train_loss: 0.8834, step time: 1.0417
# 7/388, train_loss: 0.8525, step time: 1.0335
# 8/388, train_loss: 0.7684, step time: 1.0448
# 9/388, train_loss: 0.9606, step time: 1.1233
# 10/388, train_loss: 0.7854, step time: 1.0898
# 11/388, train_loss: 0.9430, step time: 1.0830
# 12/388, train_loss: 0.8411, step time: 1.0378
# 13/388, train_loss: 0.8712, step time: 1.1214
# 14/388, train_loss: 0.8862, step time: 1.0397
# 15/388, train_loss: 0.8999, step time: 1.1062
# 16/388, train_loss: 0.9379, step time: 1.1040
# 17/388, train_loss: 0.7472, step time: 1.1332
# 18/388, train_loss: 0.9493, step time: 1.0863
# 19/388, train_loss: 0.9691, step time: 1.0741
# 20/388, train_loss: 0.9494, step time: 1.0932
# 21/388, train_loss: 0.8960, step time: 1.0534
# 22/388, train_loss: 0.8134, step time: 1.1046
# 23/388, train_loss: 0.9075, step time: 1.0458
# 24/388, train_loss: 0.9141, step time: 1.0645
# 25/388, train_loss: 0.8926, step time: 1.0521
# 26/388, train_loss: 0.9530, step time: 1.0361
# 27/388, train_loss: 0.8170, step time: 1.0978
# 28/388, train_loss: 0.9850, step time: 1.0567
# 29/388, train_loss: 0.8930, step time: 1.0796
# 30/388, train_loss: 0.9205, step time: 1.0510
# 31/388, train_loss: 0.8487, step time: 1.1158
# 32/388, train_loss: 0.7151, step time: 1.0955
# 33/388, train_loss: 0.9777, step time: 1.0919
# 34/388, train_loss: 0.7544, step time: 1.0546
# 35/388, train_loss: 0.8713, step time: 1.1216
# 36/388, train_loss: 0.9164, step time: 1.0401
# 37/388, train_loss: 0.8368, step time: 1.0710
# 38/388, train_loss: 0.7490, step time: 1.0486
# 39/388, train_loss: 0.8786, step time: 1.0624
# 40/388, train_loss: 0.8422, step time: 1.0493
# 41/388, train_loss: 0.8877, step time: 1.0686
# 42/388, train_loss: 0.9077, step time: 1.0272
# 43/388, train_loss: 0.8822, step time: 1.0306
# 44/388, train_loss: 0.9227, step time: 1.0321
# 45/388, train_loss: 0.9347, step time: 1.0993
# 46/388, train_loss: 0.8267, step time: 1.0835
# 47/388, train_loss: 0.9664, step time: 1.0526
# 48/388, train_loss: 0.9569, step time: 1.0673
# 49/388, train_loss: 0.8395, step time: 1.0473
# 50/388, train_loss: 0.8384, step time: 1.0857
# 51/388, train_loss: 0.9136, step time: 1.0406
# 52/388, train_loss: 0.9865, step time: 1.0998
# 53/388, train_loss: 0.9492, step time: 1.1074
# 54/388, train_loss: 0.6816, step time: 1.0423
# 55/388, train_loss: 0.9698, step time: 1.0843
# 56/388, train_loss: 0.8718, step time: 1.0499
# 57/388, train_loss: 0.8775, step time: 1.0914
# 58/388, train_loss: 0.9589, step time: 1.0397
# 59/388, train_loss: 0.8479, step time: 1.0457
# 60/388, train_loss: 0.7905, step time: 1.0724
# 61/388, train_loss: 0.8614, step time: 1.0483
# 62/388, train_loss: 0.8776, step time: 1.0672
# 63/388, train_loss: 0.8846, step time: 1.0531
# 64/388, train_loss: 0.9125, step time: 1.0925
# 65/388, train_loss: 0.7618, step time: 1.0578
# 66/388, train_loss: 0.9304, step time: 1.0887
# 67/388, train_loss: 0.9334, step time: 1.0447
# 68/388, train_loss: 0.8742, step time: 1.0499
# 69/388, train_loss: 0.9798, step time: 1.0325
# 70/388, train_loss: 0.8496, step time: 1.0329
# 71/388, train_loss: 0.8867, step time: 1.0408
# 72/388, train_loss: 0.8524, step time: 1.0551
# 73/388, train_loss: 0.8280, step time: 1.0436
# 74/388, train_loss: 0.7473, step time: 1.0335
# 75/388, train_loss: 0.8917, step time: 1.0327
# 76/388, train_loss: 0.8916, step time: 1.0428
# 77/388, train_loss: 0.9790, step time: 1.0364
# 78/388, train_loss: 0.8880, step time: 1.0992
# 79/388, train_loss: 0.9220, step time: 1.0486
# 80/388, train_loss: 0.8992, step time: 1.0490
# 81/388, train_loss: 0.9299, step time: 1.0512
# 82/388, train_loss: 0.9112, step time: 1.0269
# 83/388, train_loss: 0.7906, step time: 1.0480
# 84/388, train_loss: 0.8860, step time: 1.0444
# 85/388, train_loss: 0.9511, step time: 1.0353
# 86/388, train_loss: 0.8569, step time: 1.0964
# 87/388, train_loss: 0.8746, step time: 1.0441
# 88/388, train_loss: 0.9634, step time: 1.0413
# 89/388, train_loss: 0.9884, step time: 1.0439
# 90/388, train_loss: 0.9449, step time: 1.0498
# 91/388, train_loss: 0.8307, step time: 1.0892
# 92/388, train_loss: 0.9910, step time: 1.1084
# 93/388, train_loss: 0.9714, step time: 1.1117
# 94/388, train_loss: 0.9392, step time: 1.0456
# 95/388, train_loss: 0.9806, step time: 1.0434
# 96/388, train_loss: 0.9098, step time: 1.0554
# 97/388, train_loss: 0.9284, step time: 1.0706
# 98/388, train_loss: 0.8231, step time: 1.1352
# 99/388, train_loss: 0.8862, step time: 1.1317
# 100/388, train_loss: 0.8140, step time: 1.0405
# 101/388, train_loss: 0.7881, step time: 1.1241
# 102/388, train_loss: 0.8416, step time: 1.0489
# 103/388, train_loss: 0.8549, step time: 1.0646
# 104/388, train_loss: 0.9720, step time: 1.1349
# 105/388, train_loss: 0.9240, step time: 1.0569
# 106/388, train_loss: 0.9910, step time: 1.0564
# 107/388, train_loss: 0.8022, step time: 1.0401
# 108/388, train_loss: 0.9424, step time: 1.0645
# 109/388, train_loss: 0.8918, step time: 1.0542
# 110/388, train_loss: 0.9198, step time: 1.0554
# 111/388, train_loss: 0.9590, step time: 1.0462
# 112/388, train_loss: 0.7724, step time: 1.1028
# 113/388, train_loss: 0.8815, step time: 1.0498
# 114/388, train_loss: 0.9097, step time: 1.0856
# 115/388, train_loss: 0.9115, step time: 1.0583
# 116/388, train_loss: 0.9012, step time: 1.0668
# 117/388, train_loss: 0.8190, step time: 1.0427
# 118/388, train_loss: 0.8277, step time: 1.0503
# 119/388, train_loss: 0.8871, step time: 1.0346
# 120/388, train_loss: 0.7410, step time: 1.0575
# 121/388, train_loss: 0.9297, step time: 1.0415
# 122/388, train_loss: 0.8950, step time: 1.0370
# 123/388, train_loss: 0.9039, step time: 1.0463
# 124/388, train_loss: 0.8649, step time: 1.0492
# 125/388, train_loss: 0.8796, step time: 1.0661
# 126/388, train_loss: 0.8374, step time: 1.0474
# 127/388, train_loss: 0.9624, step time: 1.1271
# 128/388, train_loss: 0.8090, step time: 1.0506
# 129/388, train_loss: 0.9294, step time: 1.0416
# 130/388, train_loss: 0.8856, step time: 1.0431
# 131/388, train_loss: 0.9008, step time: 1.0539
# 132/388, train_loss: 0.9056, step time: 1.0400
# 133/388, train_loss: 0.9285, step time: 1.0570
# 134/388, train_loss: 0.8558, step time: 1.0442
# 135/388, train_loss: 0.9003, step time: 1.0657
# 136/388, train_loss: 0.9743, step time: 1.0419
# 137/388, train_loss: 0.9438, step time: 1.0311
# 138/388, train_loss: 0.9365, step time: 1.1012
# 139/388, train_loss: 0.9195, step time: 1.0411
# 140/388, train_loss: 0.9182, step time: 1.0549
# 141/388, train_loss: 0.7611, step time: 1.0452
# 142/388, train_loss: 0.9326, step time: 1.0495
# 143/388, train_loss: 0.9830, step time: 1.0439
# 144/388, train_loss: 0.8699, step time: 1.0342
# 145/388, train_loss: 0.9147, step time: 1.0412
# 146/388, train_loss: 0.7694, step time: 1.0514
# 147/388, train_loss: 0.8452, step time: 1.0503
# 148/388, train_loss: 0.8974, step time: 1.0436
# 149/388, train_loss: 0.9639, step time: 1.1011
# 150/388, train_loss: 0.9593, step time: 1.0545
# 151/388, train_loss: 0.8926, step time: 1.0470
# 152/388, train_loss: 0.8394, step time: 1.0465
# 153/388, train_loss: 0.9884, step time: 1.0397
# 154/388, train_loss: 0.9207, step time: 1.0364
# 155/388, train_loss: 0.9872, step time: 1.0430
# 156/388, train_loss: 0.9038, step time: 1.0725
# 157/388, train_loss: 0.9825, step time: 1.0910
# 158/388, train_loss: 0.9940, step time: 1.0306
# 159/388, train_loss: 0.9229, step time: 1.0936
# 160/388, train_loss: 0.9080, step time: 1.0518
# 161/388, train_loss: 0.8096, step time: 1.1098
# 162/388, train_loss: 0.8958, step time: 1.1117
# 163/388, train_loss: 0.9321, step time: 1.0287
# 164/388, train_loss: 0.9316, step time: 1.0860
# 165/388, train_loss: 0.9518, step time: 1.0437
# 166/388, train_loss: 0.8826, step time: 1.0541
# 167/388, train_loss: 0.9803, step time: 1.0609
# 168/388, train_loss: 0.8624, step time: 1.0365
# 169/388, train_loss: 0.7830, step time: 1.0450
# 170/388, train_loss: 0.9438, step time: 1.0332
# 171/388, train_loss: 0.9049, step time: 1.0755
# 172/388, train_loss: 0.7791, step time: 1.0435
# 173/388, train_loss: 0.8581, step time: 1.0746
# 174/388, train_loss: 0.9337, step time: 1.0410
# 175/388, train_loss: 0.9675, step time: 1.0539
# 176/388, train_loss: 0.9715, step time: 1.0452
# 177/388, train_loss: 0.7884, step time: 1.0540
# 178/388, train_loss: 0.9412, step time: 1.1030
# 179/388, train_loss: 0.7603, step time: 1.0452
# 180/388, train_loss: 0.9151, step time: 1.0443
# 181/388, train_loss: 0.9198, step time: 1.0364
# 182/388, train_loss: 0.9471, step time: 1.0387
# 183/388, train_loss: 0.8812, step time: 1.1187
# 184/388, train_loss: 0.9249, step time: 1.1108
# 185/388, train_loss: 0.9597, step time: 1.1161
# 186/388, train_loss: 0.9079, step time: 1.0318
# 187/388, train_loss: 0.9425, step time: 1.0296
# 188/388, train_loss: 0.9498, step time: 1.0813
# 189/388, train_loss: 0.9300, step time: 1.0360
# 190/388, train_loss: 0.9797, step time: 1.0601
# 191/388, train_loss: 0.8357, step time: 1.0476
# 192/388, train_loss: 0.9446, step time: 1.0329
# 193/388, train_loss: 0.8652, step time: 1.0449
# 194/388, train_loss: 0.8709, step time: 1.0443
# 195/388, train_loss: 0.7152, step time: 1.0468
# 196/388, train_loss: 0.8198, step time: 1.0437
# 197/388, train_loss: 0.6966, step time: 1.0598
# 198/388, train_loss: 0.8869, step time: 1.0551
# 199/388, train_loss: 0.8306, step time: 1.0508
# 200/388, train_loss: 0.8047, step time: 1.0937
# 201/388, train_loss: 0.7552, step time: 1.0541
# 202/388, train_loss: 0.9153, step time: 1.1525
# 203/388, train_loss: 0.9702, step time: 1.1354
# 204/388, train_loss: 0.9470, step time: 1.1446
# 205/388, train_loss: 0.9641, step time: 1.0836
# 206/388, train_loss: 0.8477, step time: 1.0439
# 207/388, train_loss: 0.9040, step time: 1.0454
# 208/388, train_loss: 0.7973, step time: 1.0498
# 209/388, train_loss: 0.8782, step time: 1.0533
# 210/388, train_loss: 0.9057, step time: 1.0495
# 211/388, train_loss: 0.8986, step time: 1.0502
# 212/388, train_loss: 0.8310, step time: 1.0363
# 213/388, train_loss: 0.9476, step time: 1.0478
# 214/388, train_loss: 0.9439, step time: 1.0468
# 215/388, train_loss: 0.9314, step time: 1.0354
# 216/388, train_loss: 0.9648, step time: 1.0620
# 217/388, train_loss: 0.8911, step time: 1.1171
# 218/388, train_loss: 0.9113, step time: 1.0791
# 219/388, train_loss: 0.8615, step time: 1.0369
# 220/388, train_loss: 0.9665, step time: 1.0514
# 221/388, train_loss: 0.8740, step time: 1.0995
# 222/388, train_loss: 0.9825, step time: 1.0466
# 223/388, train_loss: 0.8837, step time: 1.0704
# 224/388, train_loss: 0.8324, step time: 1.0671
# 225/388, train_loss: 0.9578, step time: 1.0427
# 226/388, train_loss: 0.8438, step time: 1.0474
# 227/388, train_loss: 0.9800, step time: 1.0494
# 228/388, train_loss: 0.8873, step time: 1.1303
# 229/388, train_loss: 0.7939, step time: 1.0318
# 230/388, train_loss: 0.7905, step time: 1.0814
# 231/388, train_loss: 0.8399, step time: 1.1041
# 232/388, train_loss: 0.8290, step time: 1.1490
# 233/388, train_loss: 0.8883, step time: 1.0504
# 234/388, train_loss: 0.8779, step time: 1.0299
# 235/388, train_loss: 0.7595, step time: 1.0537
# 236/388, train_loss: 0.8114, step time: 1.0524
# 237/388, train_loss: 0.9837, step time: 1.0310
# 238/388, train_loss: 0.7805, step time: 1.0392
# 239/388, train_loss: 0.8410, step time: 1.0508
# 240/388, train_loss: 0.8904, step time: 1.0619
# 241/388, train_loss: 0.9257, step time: 1.1337
# 242/388, train_loss: 0.8993, step time: 1.0359
# 243/388, train_loss: 0.9068, step time: 1.0516
# 244/388, train_loss: 0.8464, step time: 1.0615
# 245/388, train_loss: 0.9844, step time: 1.0236
# 246/388, train_loss: 0.8138, step time: 1.0522
# 247/388, train_loss: 0.9014, step time: 1.0366
# 248/388, train_loss: 0.9588, step time: 1.0504
# 249/388, train_loss: 0.8521, step time: 1.0304
# 250/388, train_loss: 0.8838, step time: 1.0482
# 251/388, train_loss: 0.7888, step time: 1.0457
# 252/388, train_loss: 0.9571, step time: 1.0377
# 253/388, train_loss: 0.9234, step time: 1.0453
# 254/388, train_loss: 0.9026, step time: 1.0976
# 255/388, train_loss: 0.7723, step time: 1.0557
# 256/388, train_loss: 0.7613, step time: 1.1326
# 257/388, train_loss: 0.9231, step time: 1.0410
# 258/388, train_loss: 0.9295, step time: 1.0453
# 259/388, train_loss: 0.9285, step time: 1.0365
# 260/388, train_loss: 0.8846, step time: 1.0544
# 261/388, train_loss: 0.7866, step time: 1.0672
# 262/388, train_loss: 0.8816, step time: 1.0542
# 263/388, train_loss: 0.9331, step time: 1.0467
# 264/388, train_loss: 0.8280, step time: 1.0463
# 265/388, train_loss: 0.9159, step time: 1.0335
# 266/388, train_loss: 0.9109, step time: 1.0570
# 267/388, train_loss: 0.8681, step time: 1.0374
# 268/388, train_loss: 0.8304, step time: 1.0464
# 269/388, train_loss: 0.8869, step time: 1.0363
# 270/388, train_loss: 0.8086, step time: 1.0923
# 271/388, train_loss: 0.8011, step time: 1.0452
# 272/388, train_loss: 0.7491, step time: 1.0354
# 273/388, train_loss: 0.8789, step time: 1.0324
# 274/388, train_loss: 0.7652, step time: 1.0578
# 275/388, train_loss: 0.7670, step time: 1.0372
# 276/388, train_loss: 0.9281, step time: 1.0388
# 277/388, train_loss: 0.8931, step time: 1.0543
# 278/388, train_loss: 0.8418, step time: 1.0446
# 279/388, train_loss: 0.8540, step time: 1.0312
# 280/388, train_loss: 0.7755, step time: 1.0512
# 281/388, train_loss: 0.9777, step time: 1.0362
# 282/388, train_loss: 0.9853, step time: 1.0568
# 283/388, train_loss: 0.8365, step time: 1.1344
# 284/388, train_loss: 0.8539, step time: 1.1547
# 285/388, train_loss: 0.6687, step time: 1.0773
# 286/388, train_loss: 0.8441, step time: 1.0654
# 287/388, train_loss: 0.8374, step time: 1.1234
# 288/388, train_loss: 0.8907, step time: 1.0561
# 289/388, train_loss: 0.8251, step time: 1.0936
# 290/388, train_loss: 0.8013, step time: 1.0778
# 291/388, train_loss: 0.7150, step time: 1.0894
# 292/388, train_loss: 0.8398, step time: 1.0475
# 293/388, train_loss: 0.8297, step time: 1.0742
# 294/388, train_loss: 0.9530, step time: 1.0491
# 295/388, train_loss: 0.8823, step time: 1.0614
# 296/388, train_loss: 0.7984, step time: 1.0461
# 297/388, train_loss: 0.9556, step time: 1.1211
# 298/388, train_loss: 0.8231, step time: 1.0722
# 299/388, train_loss: 0.9244, step time: 1.0615
# 300/388, train_loss: 0.9199, step time: 1.1389
# 301/388, train_loss: 0.8261, step time: 1.1340
# 302/388, train_loss: 0.8400, step time: 1.0532
# 303/388, train_loss: 0.6801, step time: 1.0330
# 304/388, train_loss: 0.9420, step time: 1.0422
# 305/388, train_loss: 0.8754, step time: 1.0607
# 306/388, train_loss: 0.7324, step time: 1.0741
# 307/388, train_loss: 0.8777, step time: 1.0363
# 308/388, train_loss: 0.9215, step time: 1.0474
# 309/388, train_loss: 0.7587, step time: 1.0727
# 310/388, train_loss: 0.7169, step time: 1.0799
# 311/388, train_loss: 0.8548, step time: 1.0559
# 312/388, train_loss: 0.7438, step time: 1.0429
# 313/388, train_loss: 0.8733, step time: 1.0379
# 314/388, train_loss: 0.8398, step time: 1.0413
# 315/388, train_loss: 0.9520, step time: 1.0505
# 316/388, train_loss: 0.8158, step time: 1.0496
# 317/388, train_loss: 0.9543, step time: 1.0486
# 318/388, train_loss: 0.9129, step time: 1.0342
# 319/388, train_loss: 0.9404, step time: 1.0337
# 320/388, train_loss: 0.7224, step time: 1.0432
# 321/388, train_loss: 0.8793, step time: 1.0522
# 322/388, train_loss: 0.9304, step time: 1.0460
# 323/388, train_loss: 0.8182, step time: 1.0477
# 324/388, train_loss: 0.8523, step time: 1.0509
# 325/388, train_loss: 0.7418, step time: 1.1003
# 326/388, train_loss: 0.9211, step time: 1.1163
# 327/388, train_loss: 0.9518, step time: 1.0328
# 328/388, train_loss: 0.9628, step time: 1.0538
# 329/388, train_loss: 0.8261, step time: 1.0495
# 330/388, train_loss: 0.9786, step time: 1.0549
# 331/388, train_loss: 0.9156, step time: 1.0602
# 332/388, train_loss: 0.6392, step time: 1.0472
# 333/388, train_loss: 0.8846, step time: 1.0427
# 334/388, train_loss: 0.7429, step time: 1.1232
# 335/388, train_loss: 0.8908, step time: 1.0347
# 336/388, train_loss: 0.9767, step time: 1.0408
# 337/388, train_loss: 0.8489, step time: 1.1259
# 338/388, train_loss: 0.8576, step time: 1.0502
# 339/388, train_loss: 0.9913, step time: 1.0431
# 340/388, train_loss: 0.9706, step time: 1.0587
# 341/388, train_loss: 0.8627, step time: 1.0384
# 342/388, train_loss: 0.9356, step time: 1.0534
# 343/388, train_loss: 0.9594, step time: 1.0340
# 344/388, train_loss: 0.8839, step time: 1.0414
# 345/388, train_loss: 0.7838, step time: 1.0496
# 346/388, train_loss: 0.6938, step time: 1.0536
# 347/388, train_loss: 0.8536, step time: 1.0466
# 348/388, train_loss: 0.9681, step time: 1.0750
# 349/388, train_loss: 0.9201, step time: 1.0738
# 350/388, train_loss: 0.7177, step time: 1.0451
# 351/388, train_loss: 0.6037, step time: 1.0336
# 352/388, train_loss: 0.9510, step time: 1.0366
# 353/388, train_loss: 0.9730, step time: 1.0610
# 354/388, train_loss: 0.7741, step time: 1.0519
# 355/388, train_loss: 0.8604, step time: 1.0491
# 356/388, train_loss: 0.9547, step time: 1.0547
# 357/388, train_loss: 0.6002, step time: 1.0775
# 358/388, train_loss: 0.7786, step time: 1.0609
# 359/388, train_loss: 0.7957, step time: 1.0554
# 360/388, train_loss: 0.9365, step time: 1.0370
# 361/388, train_loss: 0.9350, step time: 1.1338
# 362/388, train_loss: 0.9427, step time: 1.0505
# 363/388, train_loss: 0.7796, step time: 1.0673
# 364/388, train_loss: 0.8836, step time: 1.0925
# 365/388, train_loss: 0.9013, step time: 1.0663
# 366/388, train_loss: 0.7070, step time: 1.0570
# 367/388, train_loss: 0.7930, step time: 1.0587
# 368/388, train_loss: 0.9001, step time: 1.0540
# 369/388, train_loss: 0.8574, step time: 1.0430
# 370/388, train_loss: 0.8138, step time: 1.0850
# 371/388, train_loss: 0.6256, step time: 1.0719
# 372/388, train_loss: 0.8811, step time: 1.0882
# 373/388, train_loss: 0.9475, step time: 1.1110
# 374/388, train_loss: 0.8068, step time: 1.0440
# 375/388, train_loss: 0.9211, step time: 1.0648
# 376/388, train_loss: 0.9877, step time: 1.0504
# 377/388, train_loss: 0.8179, step time: 1.0655
# 378/388, train_loss: 0.8238, step time: 1.0501
# 379/388, train_loss: 0.8007, step time: 1.0505
# 380/388, train_loss: 0.9345, step time: 1.0764
# 381/388, train_loss: 0.8754, step time: 1.0563
# 382/388, train_loss: 0.8623, step time: 1.0271
# 383/388, train_loss: 0.9384, step time: 1.0244
# 384/388, train_loss: 0.8995, step time: 1.0282
# 385/388, train_loss: 0.7695, step time: 1.0217
# 386/388, train_loss: 0.9391, step time: 1.0240
# 387/388, train_loss: 0.7745, step time: 1.0249
# 388/388, train_loss: 0.7978, step time: 1.0311
# epoch 2 average loss: 0.8764
# saved new best metric model
# current epoch: 2 current mean dice: 0.3993 tc: 0.4189 wt: 0.5698 et: 0.2092
# best mean dice: 0.3993 at epoch: 2
# time consuming of epoch 2 is: 572.4962
# ----------
# epoch 3/50
# 1/388, train_loss: 0.8823, step time: 1.1795
# 2/388, train_loss: 0.8547, step time: 1.0487
# 3/388, train_loss: 0.6857, step time: 1.0961
# 4/388, train_loss: 0.7917, step time: 1.0466
# 5/388, train_loss: 0.7093, step time: 1.0289
# 6/388, train_loss: 0.9112, step time: 1.0408
# 7/388, train_loss: 0.6701, step time: 1.0402
# 8/388, train_loss: 0.9105, step time: 1.1420
# 9/388, train_loss: 0.9430, step time: 1.0461
# 10/388, train_loss: 0.8756, step time: 1.0427
# 11/388, train_loss: 0.7501, step time: 1.0357
# 12/388, train_loss: 0.7423, step time: 1.1000
# 13/388, train_loss: 0.8667, step time: 1.0566
# 14/388, train_loss: 0.9154, step time: 1.1073
# 15/388, train_loss: 0.8284, step time: 1.0589
# 16/388, train_loss: 0.8187, step time: 1.0427
# 17/388, train_loss: 0.8932, step time: 1.1154
# 18/388, train_loss: 0.7079, step time: 1.0515
# 19/388, train_loss: 0.6476, step time: 1.0524
# 20/388, train_loss: 0.6380, step time: 1.1200
# 21/388, train_loss: 0.9068, step time: 1.0357
# 22/388, train_loss: 0.8104, step time: 1.0831
# 23/388, train_loss: 0.9449, step time: 1.0875
# 24/388, train_loss: 0.8275, step time: 1.1577
# 25/388, train_loss: 0.8013, step time: 1.0519
# 26/388, train_loss: 0.9238, step time: 1.0760
# 27/388, train_loss: 0.9442, step time: 1.1250
# 28/388, train_loss: 0.6039, step time: 1.0578
# 29/388, train_loss: 0.8294, step time: 1.0670
# 30/388, train_loss: 0.8639, step time: 1.0634
# 31/388, train_loss: 0.7867, step time: 1.0747
# 32/388, train_loss: 0.9821, step time: 1.0506
# 33/388, train_loss: 0.9418, step time: 1.0719
# 34/388, train_loss: 0.9392, step time: 1.0421
# 35/388, train_loss: 0.8286, step time: 1.0959
# 36/388, train_loss: 0.9865, step time: 1.1012
# 37/388, train_loss: 0.8967, step time: 1.0586
# 38/388, train_loss: 0.8160, step time: 1.0688
# 39/388, train_loss: 0.9727, step time: 1.0374
# 40/388, train_loss: 0.9872, step time: 1.0364
# 41/388, train_loss: 0.8115, step time: 1.0383
# 42/388, train_loss: 0.7952, step time: 1.0343
# 43/388, train_loss: 0.8334, step time: 1.0358
# 44/388, train_loss: 0.8161, step time: 1.0597
# 45/388, train_loss: 0.9324, step time: 1.0426
# 46/388, train_loss: 0.9075, step time: 1.0648
# 47/388, train_loss: 0.7600, step time: 1.0489
# 48/388, train_loss: 0.7431, step time: 1.0433
# 49/388, train_loss: 0.9032, step time: 1.0469
# 50/388, train_loss: 0.6683, step time: 1.0530
# 51/388, train_loss: 0.7400, step time: 1.0538
# 52/388, train_loss: 0.8082, step time: 1.0296
# 53/388, train_loss: 0.6461, step time: 1.1334
# 54/388, train_loss: 0.8928, step time: 1.1315
# 55/388, train_loss: 0.8522, step time: 1.0382
# 56/388, train_loss: 0.7081, step time: 1.0381
# 57/388, train_loss: 0.8329, step time: 1.0545
# 58/388, train_loss: 0.9049, step time: 1.0592
# 59/388, train_loss: 0.8081, step time: 1.1147
# 60/388, train_loss: 0.8460, step time: 1.0834
# 61/388, train_loss: 0.9282, step time: 1.0280
# 62/388, train_loss: 0.8263, step time: 1.0425
# 63/388, train_loss: 0.7347, step time: 1.0494
# 64/388, train_loss: 0.8896, step time: 1.0467
# 65/388, train_loss: 0.6904, step time: 1.0449
# 66/388, train_loss: 0.6704, step time: 1.1027
# 67/388, train_loss: 0.9473, step time: 1.0756
# 68/388, train_loss: 0.8925, step time: 1.0516
# 69/388, train_loss: 0.9704, step time: 1.0416
# 70/388, train_loss: 0.6987, step time: 1.0289
# 71/388, train_loss: 0.8537, step time: 1.0475
# 72/388, train_loss: 0.7632, step time: 1.0563
# 73/388, train_loss: 0.7809, step time: 1.0327
# 74/388, train_loss: 0.8047, step time: 1.0443
# 75/388, train_loss: 0.5858, step time: 1.0530
# 76/388, train_loss: 0.9714, step time: 1.0369
# 77/388, train_loss: 0.8564, step time: 1.0750
# 78/388, train_loss: 0.8125, step time: 1.0576
# 79/388, train_loss: 0.8340, step time: 1.0647
# 80/388, train_loss: 0.8683, step time: 1.0928
# 81/388, train_loss: 0.9723, step time: 1.0520
# 82/388, train_loss: 0.7887, step time: 1.0617
# 83/388, train_loss: 0.9390, step time: 1.0580
# 84/388, train_loss: 0.8028, step time: 1.0501
# 85/388, train_loss: 0.9099, step time: 1.0517
# 86/388, train_loss: 0.8178, step time: 1.0747
# 87/388, train_loss: 0.8515, step time: 1.0558
# 88/388, train_loss: 0.7313, step time: 1.0997
# 89/388, train_loss: 0.8995, step time: 1.0435
# 90/388, train_loss: 0.8381, step time: 1.0746
# 91/388, train_loss: 0.7926, step time: 1.0558
# 92/388, train_loss: 0.9202, step time: 1.0577
# 93/388, train_loss: 0.8171, step time: 1.0383
# 94/388, train_loss: 0.8009, step time: 1.0482
# 95/388, train_loss: 0.9882, step time: 1.0521
# 96/388, train_loss: 0.7423, step time: 1.0763
# 97/388, train_loss: 0.7483, step time: 1.1080
# 98/388, train_loss: 0.9134, step time: 1.0412
# 99/388, train_loss: 0.7657, step time: 1.0908
# 100/388, train_loss: 0.8020, step time: 1.0371
# 101/388, train_loss: 0.7903, step time: 1.0530
# 102/388, train_loss: 0.8544, step time: 1.0741
# 103/388, train_loss: 0.7576, step time: 1.0436
# 104/388, train_loss: 0.6619, step time: 1.0402
# 105/388, train_loss: 0.7091, step time: 1.0751
# 106/388, train_loss: 0.7813, step time: 1.0893
# 107/388, train_loss: 0.8368, step time: 1.1178
# 108/388, train_loss: 0.8089, step time: 1.0576
# 109/388, train_loss: 0.6494, step time: 1.1139
# 110/388, train_loss: 0.9846, step time: 1.0921
# 111/388, train_loss: 0.9773, step time: 1.1119
# 112/388, train_loss: 0.7668, step time: 1.0468
# 113/388, train_loss: 0.9440, step time: 1.0581
# 114/388, train_loss: 0.8778, step time: 1.1016
# 115/388, train_loss: 0.8915, step time: 1.0409
# 116/388, train_loss: 0.8508, step time: 1.0441
# 117/388, train_loss: 0.7344, step time: 1.0576
# 118/388, train_loss: 0.7640, step time: 1.0445
# 119/388, train_loss: 0.7923, step time: 1.0423
# 120/388, train_loss: 0.9095, step time: 1.0434
# 121/388, train_loss: 0.6900, step time: 1.0600
# 122/388, train_loss: 0.8704, step time: 1.0351
# 123/388, train_loss: 0.5857, step time: 1.0893
# 124/388, train_loss: 0.9194, step time: 1.0532
# 125/388, train_loss: 0.9398, step time: 1.0438
# 126/388, train_loss: 0.5331, step time: 1.0401
# 127/388, train_loss: 0.9503, step time: 1.0573
# 128/388, train_loss: 0.8597, step time: 1.0387
# 129/388, train_loss: 0.6628, step time: 1.0526
# 130/388, train_loss: 0.8132, step time: 1.0528
# 131/388, train_loss: 0.6906, step time: 1.0411
# 132/388, train_loss: 0.9620, step time: 1.0466
# 133/388, train_loss: 0.8021, step time: 1.0339
# 134/388, train_loss: 0.7535, step time: 1.0406
# 135/388, train_loss: 0.8374, step time: 1.0560
# 136/388, train_loss: 0.8018, step time: 1.1088
# 137/388, train_loss: 0.7737, step time: 1.1519
# 138/388, train_loss: 0.8251, step time: 1.0517
# 139/388, train_loss: 0.8862, step time: 1.0497
# 140/388, train_loss: 0.8019, step time: 1.0562
# 141/388, train_loss: 0.8236, step time: 1.0298
# 142/388, train_loss: 0.6941, step time: 1.0624
# 143/388, train_loss: 0.8740, step time: 1.0622
# 144/388, train_loss: 0.7411, step time: 1.0509
# 145/388, train_loss: 0.8291, step time: 1.0447
# 146/388, train_loss: 0.5194, step time: 1.0444
# 147/388, train_loss: 0.7790, step time: 1.0476
# 148/388, train_loss: 0.8489, step time: 1.0580
# 149/388, train_loss: 0.5604, step time: 1.0406
# 150/388, train_loss: 0.6957, step time: 1.0344
# 151/388, train_loss: 0.9662, step time: 1.0473
# 152/388, train_loss: 0.7617, step time: 1.0364
# 153/388, train_loss: 0.7919, step time: 1.0399
# 154/388, train_loss: 0.8956, step time: 1.0362
# 155/388, train_loss: 0.8869, step time: 1.0577
# 156/388, train_loss: 0.7459, step time: 1.0428
# 157/388, train_loss: 0.7354, step time: 1.0553
# 158/388, train_loss: 0.6653, step time: 1.0729
# 159/388, train_loss: 0.9338, step time: 1.0886
# 160/388, train_loss: 0.8608, step time: 1.1394
# 161/388, train_loss: 0.8812, step time: 1.0767
# 162/388, train_loss: 0.9319, step time: 1.0439
# 163/388, train_loss: 0.8343, step time: 1.0674
# 164/388, train_loss: 0.9107, step time: 1.0639
# 165/388, train_loss: 0.9146, step time: 1.0548
# 166/388, train_loss: 0.8474, step time: 1.0365
# 167/388, train_loss: 0.8227, step time: 1.0342
# 168/388, train_loss: 0.9483, step time: 1.0509
# 169/388, train_loss: 0.7783, step time: 1.0521
# 170/388, train_loss: 0.9055, step time: 1.0410
# 171/388, train_loss: 0.7528, step time: 1.0483
# 172/388, train_loss: 0.7806, step time: 1.0325
# 173/388, train_loss: 0.7303, step time: 1.0463
# 174/388, train_loss: 0.8392, step time: 1.0834
# 175/388, train_loss: 0.6869, step time: 1.0368
# 176/388, train_loss: 0.7703, step time: 1.0424
# 177/388, train_loss: 0.6480, step time: 1.0516
# 178/388, train_loss: 0.9122, step time: 1.0537
# 179/388, train_loss: 0.8020, step time: 1.0609
# 180/388, train_loss: 0.8033, step time: 1.0560
# 181/388, train_loss: 0.9264, step time: 1.0354
# 182/388, train_loss: 0.8505, step time: 1.0546
# 183/388, train_loss: 0.7013, step time: 1.0554
# 184/388, train_loss: 0.8724, step time: 1.0586
# 185/388, train_loss: 0.7699, step time: 1.0363
# 186/388, train_loss: 0.9609, step time: 1.0389
# 187/388, train_loss: 0.9477, step time: 1.1375
# 188/388, train_loss: 0.7829, step time: 1.1267
# 189/388, train_loss: 0.8025, step time: 1.1219
# 190/388, train_loss: 0.5474, step time: 1.1258
# 191/388, train_loss: 0.8976, step time: 1.0613
# 192/388, train_loss: 0.7495, step time: 1.0481
# 193/388, train_loss: 0.6285, step time: 1.0444
# 194/388, train_loss: 0.7980, step time: 1.0397
# 195/388, train_loss: 0.6708, step time: 1.0458
# 196/388, train_loss: 0.8026, step time: 1.0706
# 197/388, train_loss: 0.8261, step time: 1.0403
# 198/388, train_loss: 0.9752, step time: 1.0565
# 199/388, train_loss: 0.5401, step time: 1.0548
# 200/388, train_loss: 0.7250, step time: 1.0474
# 201/388, train_loss: 0.9631, step time: 1.0417
# 202/388, train_loss: 0.7280, step time: 1.0361
# 203/388, train_loss: 0.8790, step time: 1.1345
# 204/388, train_loss: 0.6350, step time: 1.1196
# 205/388, train_loss: 0.6603, step time: 1.0468
# 206/388, train_loss: 0.7521, step time: 1.1173
# 207/388, train_loss: 0.7938, step time: 1.0796
# 208/388, train_loss: 0.8671, step time: 1.0856
# 209/388, train_loss: 0.9115, step time: 1.0495
# 210/388, train_loss: 0.6916, step time: 1.0487
# 211/388, train_loss: 0.9254, step time: 1.0489
# 212/388, train_loss: 0.7427, step time: 1.0381
# 213/388, train_loss: 0.8942, step time: 1.1272
# 214/388, train_loss: 0.8244, step time: 1.1436
# 215/388, train_loss: 0.9231, step time: 1.0553
# 216/388, train_loss: 0.8211, step time: 1.0468
# 217/388, train_loss: 0.6960, step time: 1.0465
# 218/388, train_loss: 0.8594, step time: 1.0571
# 219/388, train_loss: 0.9627, step time: 1.0536
# 220/388, train_loss: 0.4706, step time: 1.0644
# 221/388, train_loss: 0.6797, step time: 1.1139
# 222/388, train_loss: 0.6676, step time: 1.0520
# 223/388, train_loss: 0.8334, step time: 1.0926
# ...
# 52/388, train_loss: 0.0918, step time: 1.0416
# 53/388, train_loss: 0.2058, step time: 1.0548
# 54/388, train_loss: 0.2632, step time: 1.0476
# 55/388, train_loss: 0.5090, step time: 1.0638
# 56/388, train_loss: 0.1448, step time: 1.1016
# 57/388, train_loss: 0.1044, step time: 1.0476
# 58/388, train_loss: 0.2236, step time: 1.0656
# 59/388, train_loss: 0.2117, step time: 1.1214
# 60/388, train_loss: 0.0787, step time: 1.1188
# 61/388, train_loss: 0.2750, step time: 1.0389
# 62/388, train_loss: 0.2544, step time: 1.0582
# 63/388, train_loss: 0.1704, step time: 1.0452
# 64/388, train_loss: 0.1426, step time: 1.1119
# 65/388, train_loss: 0.1791, step time: 1.0985
# 66/388, train_loss: 0.3743, step time: 1.0835
# 67/388, train_loss: 0.0906, step time: 1.0473
# 68/388, train_loss: 0.1750, step time: 1.0410
# 69/388, train_loss: 0.1120, step time: 1.0450
# 70/388, train_loss: 0.2315, step time: 1.0593
# 71/388, train_loss: 0.1152, step time: 1.0515
# 72/388, train_loss: 0.1255, step time: 1.0558
# 73/388, train_loss: 0.3103, step time: 1.0344
# 74/388, train_loss: 0.0545, step time: 1.0506
# 75/388, train_loss: 0.2091, step time: 1.0388
# 76/388, train_loss: 0.1442, step time: 1.0533
# 77/388, train_loss: 0.1531, step time: 1.0402
# 78/388, train_loss: 0.1217, step time: 1.0406
# 79/388, train_loss: 0.1441, step time: 1.0608
# 80/388, train_loss: 0.1915, step time: 1.0435
# 81/388, train_loss: 0.3750, step time: 1.0538
# 82/388, train_loss: 0.1774, step time: 1.0576
# 83/388, train_loss: 0.2108, step time: 1.0568
# 84/388, train_loss: 0.0908, step time: 1.0537
# 85/388, train_loss: 0.1021, step time: 1.1073
# 86/388, train_loss: 0.0896, step time: 1.1462
# 87/388, train_loss: 0.2704, step time: 1.0446
# 88/388, train_loss: 0.3747, step time: 1.0498
# 89/388, train_loss: 0.1176, step time: 1.0425
# 90/388, train_loss: 0.1716, step time: 1.0486
# 91/388, train_loss: 0.1746, step time: 1.0556
# 92/388, train_loss: 0.1356, step time: 1.0449
# 93/388, train_loss: 0.2809, step time: 1.0495
# 94/388, train_loss: 0.3620, step time: 1.1005
# 95/388, train_loss: 0.1069, step time: 1.0711
# 96/388, train_loss: 0.1307, step time: 1.0501
# 97/388, train_loss: 0.2013, step time: 1.0499
# 98/388, train_loss: 0.0766, step time: 1.0505
# 99/388, train_loss: 0.2627, step time: 1.0407
# 100/388, train_loss: 0.1011, step time: 1.0537
# 101/388, train_loss: 0.2064, step time: 1.0548
# 102/388, train_loss: 0.1725, step time: 1.0952
# 103/388, train_loss: 0.0659, step time: 1.0442
# 104/388, train_loss: 0.2072, step time: 1.0493
# 105/388, train_loss: 0.1898, step time: 1.0636
# 106/388, train_loss: 0.1755, step time: 1.0353
# 107/388, train_loss: 0.1414, step time: 1.0481
# 108/388, train_loss: 0.1411, step time: 1.0666
# 109/388, train_loss: 0.2311, step time: 1.0712
# 110/388, train_loss: 0.2522, step time: 1.0499
# 111/388, train_loss: 0.2573, step time: 1.0526
# 112/388, train_loss: 0.2122, step time: 1.0506
# 113/388, train_loss: 0.1647, step time: 1.1268
# 114/388, train_loss: 0.1503, step time: 1.0486
# 115/388, train_loss: 0.1449, step time: 1.0973
# 116/388, train_loss: 0.1272, step time: 1.0980
# 117/388, train_loss: 0.1021, step time: 1.1289
# 118/388, train_loss: 0.2114, step time: 1.0398
# 119/388, train_loss: 0.1362, step time: 1.0523
# 120/388, train_loss: 0.3750, step time: 1.0934
# 121/388, train_loss: 0.0834, step time: 1.0535
# 122/388, train_loss: 0.0985, step time: 1.0592
# 123/388, train_loss: 0.1579, step time: 1.1061
# 124/388, train_loss: 0.1528, step time: 1.0597
# 125/388, train_loss: 0.1418, step time: 1.0522
# 126/388, train_loss: 0.2163, step time: 1.0573
# 127/388, train_loss: 0.1607, step time: 1.0501
# 128/388, train_loss: 0.1787, step time: 1.0484
# 129/388, train_loss: 0.0549, step time: 1.0500
# 130/388, train_loss: 0.1971, step time: 1.0403
# 131/388, train_loss: 0.3552, step time: 1.0444
# 132/388, train_loss: 0.0681, step time: 1.0320
# 133/388, train_loss: 0.3452, step time: 1.0420
# 134/388, train_loss: 0.1095, step time: 1.1125
# 135/388, train_loss: 0.0831, step time: 1.0547
# 136/388, train_loss: 0.1981, step time: 1.0479
# 137/388, train_loss: 0.1623, step time: 1.0411
# 138/388, train_loss: 0.2757, step time: 1.0396
# 139/388, train_loss: 0.1209, step time: 1.0783
# 140/388, train_loss: 0.1774, step time: 1.0715
# 141/388, train_loss: 0.1252, step time: 1.0590
# 142/388, train_loss: 0.0944, step time: 1.0653
# 143/388, train_loss: 0.1434, step time: 1.0544
# 144/388, train_loss: 0.4837, step time: 1.0493
# 145/388, train_loss: 0.2425, step time: 1.0569
# 146/388, train_loss: 0.2825, step time: 1.0657
# 147/388, train_loss: 0.1011, step time: 1.0341
# 148/388, train_loss: 0.1417, step time: 1.0546
# 149/388, train_loss: 0.6159, step time: 1.0465
# 150/388, train_loss: 0.1387, step time: 1.0580
# 151/388, train_loss: 0.1356, step time: 1.0482
# 152/388, train_loss: 0.2679, step time: 1.0542
# 153/388, train_loss: 0.0913, step time: 1.0488
# 154/388, train_loss: 0.1661, step time: 1.0534
# 155/388, train_loss: 0.1505, step time: 1.0406
# 156/388, train_loss: 0.0989, step time: 1.0324
# 157/388, train_loss: 0.1125, step time: 1.1090
# 158/388, train_loss: 0.1203, step time: 1.0611
# 159/388, train_loss: 0.1652, step time: 1.0621
# 160/388, train_loss: 0.1221, step time: 1.0520
# 161/388, train_loss: 0.1926, step time: 1.0581
# 162/388, train_loss: 0.0502, step time: 1.0856
# 163/388, train_loss: 0.2424, step time: 1.0505
# 164/388, train_loss: 0.0899, step time: 1.0357
# 165/388, train_loss: 0.0351, step time: 1.0405
# 166/388, train_loss: 0.2903, step time: 1.0580
# 167/388, train_loss: 0.5038, step time: 1.1518
# 168/388, train_loss: 0.0536, step time: 1.0380
# 169/388, train_loss: 0.1096, step time: 1.0346
# 170/388, train_loss: 0.1546, step time: 1.0802
# 171/388, train_loss: 0.2412, step time: 1.0538
# 172/388, train_loss: 0.3010, step time: 1.0881
# 173/388, train_loss: 0.2256, step time: 1.0997
# 174/388, train_loss: 0.2047, step time: 1.0441
# 175/388, train_loss: 0.2269, step time: 1.0471
# 176/388, train_loss: 0.4018, step time: 1.0530
# 177/388, train_loss: 0.2186, step time: 1.0495
# 178/388, train_loss: 0.0680, step time: 1.0333
# 179/388, train_loss: 0.0696, step time: 1.0412
# 180/388, train_loss: 0.1615, step time: 1.0433
# 181/388, train_loss: 0.2864, step time: 1.0521
# 182/388, train_loss: 0.3934, step time: 1.0471
# 183/388, train_loss: 0.3184, step time: 1.0355
# 184/388, train_loss: 0.1443, step time: 1.0546
# 185/388, train_loss: 0.2122, step time: 1.0382
# 186/388, train_loss: 0.1046, step time: 1.0464
# 187/388, train_loss: 0.4053, step time: 1.0667
# 188/388, train_loss: 0.1209, step time: 1.0367
# 189/388, train_loss: 0.2953, step time: 1.1061
# 190/388, train_loss: 0.1792, step time: 1.0964
# 191/388, train_loss: 0.1435, step time: 1.0437
# 192/388, train_loss: 0.4034, step time: 1.0514
# 193/388, train_loss: 0.1134, step time: 1.0320
# 194/388, train_loss: 0.2228, step time: 1.1249
# 195/388, train_loss: 0.1957, step time: 1.0549
# 196/388, train_loss: 0.2447, step time: 1.0814
# 197/388, train_loss: 0.2046, step time: 1.0416
# 198/388, train_loss: 0.0918, step time: 1.0431
# 199/388, train_loss: 0.3339, step time: 1.0457
# 200/388, train_loss: 0.1683, step time: 1.0816
# 201/388, train_loss: 0.0970, step time: 1.0739
# 202/388, train_loss: 0.0886, step time: 1.0484
# 203/388, train_loss: 0.2316, step time: 1.1270
# 204/388, train_loss: 0.1002, step time: 1.0999
# 205/388, train_loss: 0.0687, step time: 1.0412
# 206/388, train_loss: 0.1069, step time: 1.0533
# 207/388, train_loss: 0.0886, step time: 1.0665
# 208/388, train_loss: 0.1571, step time: 1.0478
# 209/388, train_loss: 0.4677, step time: 1.0791
# 210/388, train_loss: 0.1463, step time: 1.0494
# 211/388, train_loss: 0.3019, step time: 1.0441
# 212/388, train_loss: 0.1130, step time: 1.0483
# 213/388, train_loss: 0.2643, step time: 1.0409
# 214/388, train_loss: 0.2117, step time: 1.0523
# 215/388, train_loss: 0.1824, step time: 1.0438
# 216/388, train_loss: 0.0948, step time: 1.0505
# 217/388, train_loss: 0.0663, step time: 1.0972
# 218/388, train_loss: 0.2699, step time: 1.0456
# 219/388, train_loss: 0.1080, step time: 1.0574
# 220/388, train_loss: 0.1814, step time: 1.1218
# 221/388, train_loss: 0.0756, step time: 1.1299
# 222/388, train_loss: 0.1622, step time: 1.0754
# 223/388, train_loss: 0.2125, step time: 1.0784
# 224/388, train_loss: 0.0642, step time: 1.1237
# 225/388, train_loss: 0.2098, step time: 1.0397
# 226/388, train_loss: 0.0968, step time: 1.0864
# 227/388, train_loss: 0.0614, step time: 1.0637
# 228/388, train_loss: 0.2214, step time: 1.0651
# 229/388, train_loss: 0.0915, step time: 1.0786
# 230/388, train_loss: 0.0910, step time: 1.0533
# 231/388, train_loss: 0.1962, step time: 1.0538
# 232/388, train_loss: 0.1896, step time: 1.1030
# 233/388, train_loss: 0.0909, step time: 1.0577
# 234/388, train_loss: 0.1871, step time: 1.0944
# 235/388, train_loss: 0.0703, step time: 1.1198
# 236/388, train_loss: 0.1997, step time: 1.0536
# 237/388, train_loss: 0.1191, step time: 1.0705
# 238/388, train_loss: 0.1299, step time: 1.0549
# 239/388, train_loss: 0.2601, step time: 1.0618
# 240/388, train_loss: 0.0898, step time: 1.0544
# 241/388, train_loss: 0.1033, step time: 1.0512
# 242/388, train_loss: 0.1561, step time: 1.0435
# 243/388, train_loss: 0.1256, step time: 1.0623
# 244/388, train_loss: 0.0527, step time: 1.0346
# 245/388, train_loss: 0.1265, step time: 1.0502
# 246/388, train_loss: 0.3654, step time: 1.0647
# 247/388, train_loss: 0.0747, step time: 1.0613
# 248/388, train_loss: 0.2005, step time: 1.0533
# 249/388, train_loss: 0.1643, step time: 1.0533
# 250/388, train_loss: 0.0931, step time: 1.0372
# 251/388, train_loss: 0.1694, step time: 1.0356
# 252/388, train_loss: 0.1106, step time: 1.0520
# 253/388, train_loss: 0.1955, step time: 1.0469
# 254/388, train_loss: 0.2347, step time: 1.0535
# 255/388, train_loss: 0.1424, step time: 1.0375
# 256/388, train_loss: 0.0433, step time: 1.0465
# 257/388, train_loss: 0.1008, step time: 1.0455
# 258/388, train_loss: 0.2488, step time: 1.0517
# 259/388, train_loss: 0.1459, step time: 1.0448
# 260/388, train_loss: 0.2032, step time: 1.0384
# 261/388, train_loss: 0.0996, step time: 1.0478
# 262/388, train_loss: 0.1073, step time: 1.0522
# 263/388, train_loss: 0.0804, step time: 1.0463
# 264/388, train_loss: 0.1160, step time: 1.0322
# 265/388, train_loss: 0.2758, step time: 1.0394
# 266/388, train_loss: 0.5335, step time: 1.0448
# 267/388, train_loss: 0.1021, step time: 1.0492
# 268/388, train_loss: 0.2757, step time: 1.0393
# 269/388, train_loss: 0.1178, step time: 1.0415
# 270/388, train_loss: 0.0796, step time: 1.0559
# 271/388, train_loss: 0.1212, step time: 1.0754
# 272/388, train_loss: 0.1061, step time: 1.0481
# 273/388, train_loss: 0.0573, step time: 1.0505
# 274/388, train_loss: 0.2853, step time: 1.0506
# 275/388, train_loss: 0.1277, step time: 1.0550
# 276/388, train_loss: 0.1324, step time: 1.0466
# 277/388, train_loss: 0.0722, step time: 1.0538
# 278/388, train_loss: 0.1623, step time: 1.0455
# 279/388, train_loss: 0.2939, step time: 1.0624
# 280/388, train_loss: 0.2268, step time: 1.0500
# 281/388, train_loss: 0.1991, step time: 1.0446
# 282/388, train_loss: 0.1532, step time: 1.0474
# 283/388, train_loss: 0.2936, step time: 1.0603
# 284/388, train_loss: 0.2257, step time: 1.0588
# 285/388, train_loss: 0.2677, step time: 1.0598
# 286/388, train_loss: 0.2256, step time: 1.0597
# 287/388, train_loss: 0.1372, step time: 1.0365
# 288/388, train_loss: 0.2269, step time: 1.0833
# 289/388, train_loss: 0.1747, step time: 1.0612
# 290/388, train_loss: 0.2742, step time: 1.0479
# 291/388, train_loss: 0.1668, step time: 1.1189
# 292/388, train_loss: 0.1588, step time: 1.1051
# 293/388, train_loss: 0.1895, step time: 1.0478
# 294/388, train_loss: 0.2049, step time: 1.0549
# 295/388, train_loss: 0.2124, step time: 1.0709
# 296/388, train_loss: 0.1991, step time: 1.0493
# 297/388, train_loss: 0.2391, step time: 1.0495
# 298/388, train_loss: 0.1822, step time: 1.0522
# 299/388, train_loss: 0.1068, step time: 1.0607
# 300/388, train_loss: 0.2774, step time: 1.0450
# 301/388, train_loss: 0.0711, step time: 1.1196
# 302/388, train_loss: 0.3973, step time: 1.1474
# 303/388, train_loss: 0.5069, step time: 1.1113
# 304/388, train_loss: 0.2248, step time: 1.0418
# 305/388, train_loss: 0.1344, step time: 1.0519
# 306/388, train_loss: 0.2921, step time: 1.0575
# 307/388, train_loss: 0.1729, step time: 1.0472
# 308/388, train_loss: 0.1690, step time: 1.0312
# 309/388, train_loss: 0.2010, step time: 1.0399
# 310/388, train_loss: 0.1069, step time: 1.0505
# 311/388, train_loss: 0.1698, step time: 1.0508
# 312/388, train_loss: 0.2767, step time: 1.0471
# 313/388, train_loss: 0.0508, step time: 1.0404
# 314/388, train_loss: 0.0965, step time: 1.0668
# 315/388, train_loss: 0.1195, step time: 1.0621
# 316/388, train_loss: 0.4212, step time: 1.0650
# 317/388, train_loss: 0.0950, step time: 1.0526
# 318/388, train_loss: 0.0960, step time: 1.0348
# 319/388, train_loss: 0.0577, step time: 1.0494
# 320/388, train_loss: 0.1525, step time: 1.0689
# 321/388, train_loss: 0.1045, step time: 1.0558
# 322/388, train_loss: 0.1338, step time: 1.0404
# 323/388, train_loss: 0.2001, step time: 1.0358
# 324/388, train_loss: 0.1803, step time: 1.0362
# 325/388, train_loss: 0.1719, step time: 1.0524
# 326/388, train_loss: 0.2499, step time: 1.0509
# 327/388, train_loss: 0.0330, step time: 1.0398
# 328/388, train_loss: 0.2638, step time: 1.0960
# 329/388, train_loss: 0.1937, step time: 1.0923
# 330/388, train_loss: 0.5586, step time: 1.2258
# 331/388, train_loss: 0.0891, step time: 1.0512
# 332/388, train_loss: 0.3532, step time: 1.0802
# 333/388, train_loss: 0.1582, step time: 1.0567
# 334/388, train_loss: 0.2485, step time: 1.1065
# 335/388, train_loss: 0.1307, step time: 1.0943
# 336/388, train_loss: 0.1462, step time: 1.0465
# 337/388, train_loss: 0.0992, step time: 1.0332
# 338/388, train_loss: 0.0942, step time: 1.0533
# 339/388, train_loss: 0.1236, step time: 1.0519
# 340/388, train_loss: 0.1046, step time: 1.0547
# 341/388, train_loss: 0.1343, step time: 1.0460
# 342/388, train_loss: 0.1067, step time: 1.0481
# 343/388, train_loss: 0.2242, step time: 1.0335
# 344/388, train_loss: 0.2236, step time: 1.0595
# 345/388, train_loss: 0.1450, step time: 1.0741
# 346/388, train_loss: 0.0770, step time: 1.0656
# 347/388, train_loss: 0.1452, step time: 1.0619
# 348/388, train_loss: 0.1472, step time: 1.0335
# 349/388, train_loss: 0.0976, step time: 1.0495
# 350/388, train_loss: 0.1246, step time: 1.0655
# 351/388, train_loss: 0.1155, step time: 1.0379
# 352/388, train_loss: 0.2557, step time: 1.0435
# 353/388, train_loss: 0.2933, step time: 1.0310
# 354/388, train_loss: 0.0981, step time: 1.0578
# 355/388, train_loss: 0.2343, step time: 1.0838
# 356/388, train_loss: 0.3393, step time: 1.1312
# 357/388, train_loss: 0.2790, step time: 1.1415
# 358/388, train_loss: 0.0809, step time: 1.0575
# 359/388, train_loss: 0.1011, step time: 1.0521
# 360/388, train_loss: 0.2097, step time: 1.0795
# 361/388, train_loss: 0.1137, step time: 1.0512
# 362/388, train_loss: 0.2307, step time: 1.0530
# 363/388, train_loss: 0.0602, step time: 1.0390
# 364/388, train_loss: 0.2432, step time: 1.0528
# 365/388, train_loss: 0.1759, step time: 1.0475
# 366/388, train_loss: 0.1890, step time: 1.0314
# 367/388, train_loss: 0.0978, step time: 1.0464
# 368/388, train_loss: 0.2065, step time: 1.0601
# 369/388, train_loss: 0.1495, step time: 1.0503
# 370/388, train_loss: 0.1998, step time: 1.0662
# 371/388, train_loss: 0.2779, step time: 1.0550
# 372/388, train_loss: 0.1066, step time: 1.0343
# 373/388, train_loss: 0.0832, step time: 1.0514
# 374/388, train_loss: 0.0763, step time: 1.0501
# 375/388, train_loss: 0.0795, step time: 1.0460
# 376/388, train_loss: 0.1858, step time: 1.0539
# 377/388, train_loss: 0.2158, step time: 1.0327
# 378/388, train_loss: 0.1006, step time: 1.0488
# 379/388, train_loss: 0.1229, step time: 1.0467
# 380/388, train_loss: 0.1610, step time: 1.0508
# 381/388, train_loss: 0.4209, step time: 1.0406
# 382/388, train_loss: 0.1058, step time: 1.0304
# 383/388, train_loss: 0.2200, step time: 1.0293
# 384/388, train_loss: 0.3826, step time: 1.0334
# 385/388, train_loss: 0.3588, step time: 1.0299
# 386/388, train_loss: 0.0925, step time: 1.0305
# 387/388, train_loss: 0.4435, step time: 1.0323
# 388/388, train_loss: 0.0653, step time: 1.0226
# epoch 50 average loss: 0.1790
# current epoch: 50 current mean dice: 0.7647 tc: 0.8141 wt: 0.9030 et: 0.5769
# best mean dice: 0.7648 at epoch: 49
# time consuming of epoch 50 is: 567.6726

# %%
print(f"train completed, best_metric: {best_metric:.4f} at epoch: {best_metric_epoch}, total time: {total_time}.")
# Out:
# train completed, best_metric: 0.7648 at epoch: 49, total time: 28485.7510535717.

# %% [markdown]
# ## Plot the loss and metric

# %%
plt.figure("train", (12, 6))
plt.subplot(1, 2, 1)
plt.title("Epoch Average Loss")
x = [i + 1 for i in range(len(epoch_loss_values))]
y = epoch_loss_values
plt.xlabel("epoch")
plt.plot(x, y, color="red")
plt.subplot(1, 2, 2)
plt.title("Val Mean Dice")
x = [val_interval * (i + 1) for i in range(len(metric_values))]
y = metric_values
plt.xlabel("epoch")
plt.plot(x, y, color="green")
plt.show()

plt.figure("train", (18, 6))
plt.subplot(1, 3, 1)
plt.title("Val Mean Dice TC")
x = [val_interval * (i + 1) for i in range(len(metric_values_tc))]
y = metric_values_tc
plt.xlabel("epoch")
plt.plot(x, y, color="blue")
plt.subplot(1, 3, 2)
plt.title("Val Mean Dice WT")
x = [val_interval * (i + 1) for i in range(len(metric_values_wt))]
y = metric_values_wt
plt.xlabel("epoch")
plt.plot(x, y, color="brown")
plt.subplot(1, 3, 3)
plt.title("Val Mean Dice ET")
x = [val_interval * (i + 1) for i in range(len(metric_values_et))]
y = metric_values_et
plt.xlabel("epoch")
plt.plot(x, y, color="purple")
plt.show()

# %% [markdown]
# ## Check best pytorch model output with the input image and label

# %%
model.load_state_dict(torch.load(os.path.join(root_dir, "best_metric_model.pth")))
model.eval()
with torch.no_grad():
    # select one image to evaluate and visualize the model output
    val_input = val_ds[6]["image"].unsqueeze(0).to(device)
    roi_size = (128, 128, 64)
    sw_batch_size = 4
    val_output = inference(val_input)
    val_output = post_trans(val_output[0])
    plt.figure("image", (24, 6))
    for i in range(4):
        plt.subplot(1, 4, i + 1)
        plt.title(f"image channel {i}")
        plt.imshow(val_ds[6]["image"][i, :, :, 70].detach().cpu(), cmap="gray")
    plt.show()
    # visualize the 3 channels label corresponding to this image
    plt.figure("label", (18, 6))
    for i in range(3):
        plt.subplot(1, 3, i + 1)
        plt.title(f"label channel {i}")
        plt.imshow(val_ds[6]["label"][i, :, :, 70].detach().cpu())
    plt.show()
    # visualize the 3 channels model output corresponding to this image
    plt.figure("output", (18, 6))
    for i in range(3):
        plt.subplot(1, 3, i + 1)
        plt.title(f"output channel {i}")
        plt.imshow(val_output[i, :, :, 70].detach().cpu())
    plt.show()
# Out:
# /tmp/ipykernel_30/3380591432.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(os.path.join(root_dir, "best_metric_model.pth")))
# /tmp/ipykernel_30/1147902317.py:37: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():

# %% [markdown]
# ## Evaluation on original image spacings

# %%
val_org_transforms = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        EnsureChannelFirstd(keys=["image"]),
        ConvertToMultiChannelBasedOnBratsClassesd(keys="label"),
        Orientationd(keys=["image"], axcodes="RAS"),
        Spacingd(keys=["image"], pixdim=(1.0, 1.0, 1.0), mode="bilinear"),
        NormalizeIntensityd(keys="image", nonzero=True, channel_wise=True),
    ]
)

val_org_ds = DecathlonDataset(
    root_dir=root_dir,
    task="Task01_BrainTumour",
    transform=val_org_transforms,
    section="validation",
    download=False,
    num_workers=4,
    cache_num=0,
)
val_org_loader = DataLoader(val_org_ds, batch_size=1, shuffle=False, num_workers=4)

post_transforms = Compose(
    [
        Invertd(
            keys="pred",
            transform=val_org_transforms,
            orig_keys="image",
            meta_keys="pred_meta_dict",
            orig_meta_keys="image_meta_dict",
            meta_key_postfix="meta_dict",
            nearest_interp=False,
            to_tensor=True,
            device="cpu",
        ),
        Activationsd(keys="pred", sigmoid=True),
        AsDiscreted(keys="pred", threshold=0.5),
    ]
)

# %%
model.load_state_dict(torch.load(os.path.join(root_dir, "best_metric_model.pth")))
model.eval()

with torch.no_grad():
    for val_data in val_org_loader:
        val_inputs = val_data["image"].to(device)
        val_data["pred"] = inference(val_inputs)
        val_data = [post_transforms(i) for i in decollate_batch(val_data)]
        val_outputs, val_labels = from_engine(["pred", "label"])(val_data)
        dice_metric(y_pred=val_outputs, y=val_labels)
        dice_metric_batch(y_pred=val_outputs, y=val_labels)

    metric_org = dice_metric.aggregate().item()
    metric_batch_org = dice_metric_batch.aggregate()

    dice_metric.reset()
    dice_metric_batch.reset()

metric_tc, metric_wt, metric_et = metric_batch_org[0].item(), metric_batch_org[1].item(), metric_batch_org[2].item()

print("Metric on original image spacing: ", metric_org)
print(f"metric_tc: {metric_tc:.4f}")
print(f"metric_wt: {metric_wt:.4f}")
print(f"metric_et: {metric_et:.4f}")
# Out:
# /tmp/ipykernel_30/2081960018.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(os.path.join(root_dir, "best_metric_model.pth")))
# /tmp/ipykernel_30/1147902317.py:37: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Metric on original image spacing:  0.7648293375968933
# metric_tc: 0.8142
# metric_wt: 0.9031
# metric_et: 0.5772

# %% [markdown]
# ## Cleanup data directory
#
# Remove directory if a temporary was used.

# %%
if directory is None:
    shutil.rmtree(root_dir)
